# %% [markdown]
# # MovieLens Recommender System Using ALS

# %% [markdown]
# ## Dataset source:
# ### MovieLens Latest Datasets: https://grouplens.org/datasets/movielens/latest/
#
# ***IMPORTANT NOTE:*** The file containing this notebook is meant to be unzipped/placed in your "C:/BigData/~notebookJupyter/" library. If this is not the case, you will either need to alter the filepath (dirPath) below or move the folder into the correct directory.

# %% [markdown]
# ## Launch Spark Session on Jupyter

# %%
#********PySpark connect code start********#
import findspark
findspark.init()
import pyspark
from pyspark import SparkContext
from pyspark import SQLContext
from pyspark.sql import SparkSession
sc = SparkContext.getOrCreate()
spark = SparkSession.builder.getOrCreate()
print(sc.version)
print(spark.version)
#********PySpark connect code end********#
# Out:
# 2.4.8
# 2.4.8

# %%
#import pyspark.pandas as ps
#pyspark.sql.DataFrame.to_pandas_on_spark
import pandas as ps
from pyspark.sql import functions as F
from pyspark.sql.functions import udf,col, when
from pyspark.sql import SQLContext
from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql.types import IntegerType
import numpy as np
from IPython.display import Image
from IPython.display import display

import matplotlib.pyplot as plt

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
sc =spark.sparkContext
sqlContext = SQLContext(sc)

# %% [markdown]
# ## Dataset Preprocessing and Preparation:##
#
# The MovieLens DataSet is contained in 4 CSV files:
#
# 1.   ratings.csv - Dataset ratings of movies (represented by a unique movieID) by every user (each represented by a unique userID)
# 2.   movies.csv - DataSet list of movies by title, associated movieID and the genres of each movie
# 3.   tags.csv - Tags attributed to each movie by individual users
# 4.   links.csv - Identifiers that can be used to link to other sources of movie data
#
#
# Here we load the data into dataframes:

# %%
#**************************************************************************
# Infere CSV schema
#**************************************************************************

#TODO: NEED TO CHANGE UP THE DIRECTORY SO THAT NOTEBOOK CAN RUN INSTANTANEOUSLY WITHOUT EDITING THE PATH FOR EACH INDIVIDUAL USER
#dirPath = "C:/BigData/~Data/movieLensData/ml-latest-small/ml-latest-small/"
dirPath = "C:/BigData/~notebookJupyter/ece552project_team03/movieLensData/ml-latest-small/ml-latest-small/"


tags_fileName = "tags.csv"
movies_fileName = "movies.csv"
ratings_fileName = "ratings.csv"
links_fileName = "links.csv"



tags_df = spark.read.format("csv"). \
            option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ","). \
            option("ignoreLeadingWhiteSpace","true").option("ignoreTrailingWhiteSpace","true"). \
            option("inferschema","true"). \
            load(dirPath + tags_fileName)
        
print(tags_df.count())
tags_df.printSchema()


movies_df = spark.read.format("csv"). \
            option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ","). \
            option("ignoreLeadingWhiteSpace","true").option("ignoreTrailingWhiteSpace","true"). \
            option("inferschema","true"). \
            load(dirPath + movies_fileName)
        
print(movies_df.count())
movies_df.printSchema()


rating_df = spark.read.format("csv"). \
            option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ","). \
            option("ignoreLeadingWhiteSpace","true").option("ignoreTrailingWhiteSpace","true"). \
            option("inferschema","true"). \
            load(dirPath + ratings_fileName)
        
print(rating_df.count())
rating_df.printSchema()

links_df = spark.read.format("csv"). \
            option("header", "true").option("mode", "DROPMALFORMED").option("delimiter", ","). \
            option("ignoreLeadingWhiteSpace","true").option("ignoreTrailingWhiteSpace","true"). \
            option("inferschema","true"). \
            load(dirPath + links_fileName)
        
print(links_df.count())
links_df.printSchema()
# Out:
# 3683
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- tag: string (nullable = true)
#  |-- timestamp: integer (nullable = true)
#
# 9742
# root
#  |-- movieId: integer (nullable = true)
#  |-- title: string (nullable = true)
#  |-- genres: string (nullable = true)
#
# 100836
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- timestamp: integer (nullable = true)
#
# 9742
# root
#  |-- movieId: integer (nullable = true)
#  |-- imdbId: integer (nullable = true)
#  |-- tmdbId: integer (nullable = true)

# %%
# %%time
#**************************************************************************
# Write PARQUET files
#**************************************************************************
tags_df.coalesce(10).write.mode('overwrite').parquet(dirPath + "tags_df" + ".parquet")

movies_df.coalesce(10).write.mode('overwrite').parquet(dirPath + "movies_df" + ".parquet")

rating_df.coalesce(10).write.mode('overwrite').parquet(dirPath + "ratings_df" + ".parquet")

links_df.coalesce(10).write.mode('overwrite').parquet(dirPath + "links_df" + ".parquet")
# Out:
# Wall time: 6.18 s

# %%
# %%time
#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "tags_df" + ".parquet")
parquetdf.count()
parquetdf.show(10)
# Out:
# +------+-------+-----------------+----------+
# |userId|movieId|              tag| timestamp|
# +------+-------+-----------------+----------+
# |     2|  60756|            funny|1445714994|
# |     2|  60756|  Highly quotable|1445714996|
# |     2|  60756|     will ferrell|1445714992|
# |     2|  89774|     Boxing story|1445715207|
# |     2|  89774|              MMA|1445715200|
# |     2|  89774|        Tom Hardy|1445715205|
# |     2| 106782|            drugs|1445715054|
# |     2| 106782|Leonardo DiCaprio|1445715051|
# |     2| 106782|  Martin Scorsese|1445715056|
# |     7|  48516|     way too long|1169687325|
# +------+-------+-----------------+----------+
# only showing top 10 rows
#
# Wall time: 1.1 s

# %%
# %%time
#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "movies_df" + ".parquet")
parquetdf.count()
parquetdf.show(10)
# Out:
# +-------+--------------------+--------------------+
# |movieId|               title|              genres|
# +-------+--------------------+--------------------+
# |      1|    Toy Story (1995)|Adventure|Animati...|
# |      2|      Jumanji (1995)|Adventure|Childre...|
# |      3|Grumpier Old Men ...|      Comedy|Romance|
# |      4|Waiting to Exhale...|Comedy|Drama|Romance|
# |      5|Father of the Bri...|              Comedy|
# |      6|         Heat (1995)|Action|Crime|Thri...|
# |      7|      Sabrina (1995)|      Comedy|Romance|
# |      8| Tom and Huck (1995)|  Adventure|Children|
# |      9| Sudden Death (1995)|              Action|
# |     10|    GoldenEye (1995)|Action|Adventure|...|
# +-------+--------------------+--------------------+
# only showing top 10 rows
#
# Wall time: 559 ms

# %%
# %%time
#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "ratings_df" + ".parquet")
parquetdf.count()
parquetdf.show(10)
# Out:
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# |     1|      3|   4.0|964981247|
# |     1|      6|   4.0|964982224|
# |     1|     47|   5.0|964983815|
# |     1|     50|   5.0|964982931|
# |     1|     70|   3.0|964982400|
# |     1|    101|   5.0|964980868|
# |     1|    110|   4.0|964982176|
# |     1|    151|   5.0|964984041|
# |     1|    157|   5.0|964984100|
# +------+-------+------+---------+
# only showing top 10 rows
#
# Wall time: 575 ms

# %%
# %%time
#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "links_df" + ".parquet")
parquetdf.count()
parquetdf.show(10)
# Out:
# +-------+------+------+
# |movieId|imdbId|tmdbId|
# +-------+------+------+
# |      1|114709|   862|
# |      2|113497|  8844|
# |      3|113228| 15602|
# |      4|114885| 31357|
# |      5|113041| 11862|
# |      6|113277|   949|
# |      7|114319| 11860|
# |      8|112302| 45325|
# |      9|114576|  9091|
# |     10|113189|   710|
# +-------+------+------+
# only showing top 10 rows
#
# Wall time: 385 ms

# %%
rating_df = rating_df.withColumn("userId", rating_df["userId"].cast(IntegerType()))
rating_df = rating_df.withColumn("movieId", rating_df["movieId"].cast(IntegerType()))
rating_df = rating_df.withColumn("rating", rating_df["rating"].cast(IntegerType()))

# %%
# %%time
#**************************************************************************
# Write PARQUET file
#**************************************************************************
rating_df.coalesce(10).write.mode('overwrite').parquet(dirPath + "ratings_df" + ".parquet")
# Out:
# Wall time: 836 ms

# %%
ratings = rating_df.rdd

numRatings = ratings.count()
numUsers = ratings.map(lambda r: r[0]).distinct().count()
numMovies = ratings.map(lambda r: r[1]).distinct().count()

print("Got %d ratings from %d users on %d movies." % (numRatings, numUsers, numMovies))
# Out:
# Got 100836 ratings from 610 users on 9724 movies.

# %%
movies_counts = rating_df.groupBy(col("movieId")).agg(F.count(col("rating")).alias("counts"))
#movies_counts.show()

# %%
# %%time
#**************************************************************************
# Write PARQUET file
#**************************************************************************
movies_counts.coalesce(10).write.mode('overwrite').parquet(dirPath + "movies_counts_df" + ".parquet")


#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "movies_counts_df" + ".parquet")
parquetdf.count()
parquetdf.show()
# Out:
# +-------+------+
# |movieId|counts|
# +-------+------+
# |   1580|   165|
# |   2366|    25|
# |   3175|    75|
# |   1088|    42|
# |  32460|     4|
# |  44022|    23|
# |  96488|     4|
# |   1238|     9|
# |   1342|    11|
# |   1591|    26|
# |   1645|    51|
# |   4519|     9|
# |   2142|    10|
# |    471|    40|
# |   3997|    12|
# |    833|     6|
# |   3918|     9|
# |   7982|     4|
# |   1959|    15|
# |  68135|    10|
# +-------+------+
# only showing top 20 rows
#
# Wall time: 3.96 s

# %% [markdown]
# ## Alternating Least Squares (ALS) Matrix Factorization Model Training
#
# ### Train/Test Split

# %%
train_df, test_df = rating_df.randomSplit([0.7, 0.3])

# %%
iterations = 10
regularization_parameter = 0.1
rank = 4
errors = []
err = 0

# %%
als = ALS(maxIter=iterations, regParam=regularization_parameter, rank=4, userCol="userId", itemCol="movieId", ratingCol="rating")
model = als.fit(train_df)
predictions = model.transform(test_df)
new_predictions= predictions.filter(col('prediction') !=np.nan)
evaluator =RegressionEvaluator(metricName = "rmse", labelCol="rating", predictionCol="prediction")
rmse = evaluator.evaluate(new_predictions)
print("Root-mean-square error = " + str(rmse))
# Out:
# Root-mean-square error = 0.9283467539309946

# %%
als = ALS(maxIter=iterations, regParam=regularization_parameter, rank=5, userCol="userId", itemCol="movieId", ratingCol="rating")
model = als.fit(train_df)
predictions = model.transform(test_df)
new_predictions= predictions.filter(col('prediction') !=np.nan)
evaluator =RegressionEvaluator(metricName = "rmse", labelCol="rating", predictionCol="prediction")
rmse = evaluator.evaluate(new_predictions)
print("Root-mean-square error = " + str(rmse))
# Out:
# Root-mean-square error = 0.9356367649538887

# %% [markdown]
# ## Cross Validation with Grid Search:

# %%
for rank in range(4,10):
    als = ALS(maxIter=iterations, regParam=regularization_parameter, rank=rank, userCol="userId", itemCol="movieId", ratingCol="rating")
    model = als.fit(train_df)
    predictions = model.transform(test_df)
    new_predictions= predictions.filter(col('prediction') !=np.nan)
    evaluator =RegressionEvaluator(metricName = "rmse", labelCol="rating", predictionCol="prediction")
    rmse = evaluator.evaluate(new_predictions)
    print("Rank ", rank,": Root-mean-square error= " + str(rmse))
# Out:
# Rank  4 : Root-mean-square error= 0.9283467539309946
# Rank  5 : Root-mean-square error= 0.9356367649538886
# Rank  6 : Root-mean-square error= 0.9360138989737676
# Rank  7 : Root-mean-square error= 0.9362079402234419
# Rank  8 : Root-mean-square error= 0.9345221046097092
# Rank  9 : Root-mean-square error= 0.9377411855562303

# %% [markdown]
# Now we will build a Cross Validator to evaluate over the same range of ranks with different regularization constants. We will use sparks Cross Validator class. The CrossValidator requires an Estimator, a set of Estimator ParamMaps, and an Evaluator.
#
# The Estimator we will be using is ALS, same as above. We use a ParamGridBuilder to construct a grid of parameters to search over. With 3 values for als.regParam and 6 values for als.rank, this grid will have 3 x 6 = 18 parameter settings for CrossValidator to choose from.

# %%
als = ALS(maxIter=iterations, regParam=regularization_parameter, rank=5, userCol="userId", itemCol="movieId", ratingCol="rating")
paramGrid = ParamGridBuilder() \
     .addGrid(als.regParam, [0.1,0.01,0.18]) \
     .addGrid(als.rank, range(4, 10)) \
     .build()
evaluator = RegressionEvaluator(metricName= "rmse", labelCol ="rating", predictionCol="prediction")
crossval = CrossValidator(estimator = als,
                         estimatorParamMaps = paramGrid,
                         evaluator = evaluator,
                         numFolds= 5)
print(crossval)
cvModel = crossval.fit(train_df)
# Out:
# CrossValidator_f5bf04a4b86b

# %%
print ("Number of models tested: ", len(paramGrid))
# Out:
# Number of models tested:  18

# %%
print(crossval)
# Out:
# CrossValidator_f5bf04a4b86b

# %%
best_model = cvModel.bestModel
best_pred = best_model.transform(test_df)
best_pred = best_pred.filter(col('prediction') != np.nan)

# %%
print("**Best Model**")
# Print "Rank"
print("  Rank:", best_model._java_obj.parent().getRank())
# Print "MaxIter"
print("  MaxIter:", best_model._java_obj.parent().getMaxIter())
# Print "RegParam"
print("  RegParam:", best_model._java_obj.parent().getRegParam())
# Out:
# **Best Model**
#   Rank: 4
#   MaxIter: 10
#   RegParam: 0.1

# %%
# View the predictions
prediction1 = best_model.transform(test_df)
prediction1 = prediction1.filter(col('prediction') != np.nan)
selected = prediction1.select("userId", "movieId", "prediction")
for row in selected.collect():
    print(row)
# Out:
# Row(userId=597, movieId=471, prediction=3.9220547676086426)
# Row(userId=436, movieId=471, prediction=4.000889778137207)
# Row(userId=409, movieId=471, prediction=4.1340813636779785)
# Row(userId=599, movieId=471, prediction=2.456048011779785)
# Row(userId=218, movieId=471, prediction=3.017045497894287)
# Row(userId=57, movieId=471, prediction=3.0884809494018555)
# Row(userId=610, movieId=471, prediction=3.471186876296997)
# Row(userId=555, movieId=471, prediction=3.3653666973114014)
# Row(userId=136, movieId=471, prediction=4.5364484786987305)
# Row(userId=273, movieId=471, prediction=4.498664855957031)
# Row(userId=287, movieId=471, prediction=2.4648799896240234)
# Row(userId=32, movieId=471, prediction=4.199872016906738)
# Row(userId=414, movieId=471, prediction=3.665874481201172)
# Row(userId=608, movieId=471, prediction=1.7106698751449585)
# Row(userId=357, movieId=471, prediction=3.5380804538726807)
# Row(userId=44, movieId=833, prediction=3.4533333778381348)
# Row(userId=599, movieId=833, prediction=1.746770977973938)
# Row(userId=492, movieId=833, prediction=3.6514487266540527)
# Row(userId=463, movieId=1088, prediction=3.340989351272583)
# Row(userId=177, movieId=1088, prediction=3.174663543701172)
# Row(userId=474, movieId=1088, prediction=3.211498260498047)
# Row(userId=479, movieId=1088, prediction=2.8545620441436768)
# Row(userId=489, movieId=1088, prediction=2.4565799236297607)
# Row(userId=381, movieId=1088, prediction=3.2994935512542725)
# Row(userId=51, movieId=1088, prediction=3.4033257961273193)
# Row(userId=509, movieId=1088, prediction=3.033202648162842)
# Row(userId=226, movieId=1088, prediction=3.0882771015167236)
# Row(userId=188, movieId=1088, prediction=3.5751702785491943)
# Row(userId=42, movieId=1088, prediction=3.6716957092285156)
# Row(userId=104, movieId=1088, prediction=3.57643723487854)
# Row(userId=483, movieId=1088, prediction=2.988304615020752)
# Row(userId=517, movieId=1088, prediction=3.010974645614624)
# Row(userId=587, movieId=1238, prediction=3.365293025970459)
# Row(userId=19, movieId=1238, prediction=2.528669595718384)
# Row(userId=216, movieId=1238, prediction=3.924984931945801)
# Row(userId=469, movieId=1238, prediction=3.9001078605651855)
# Row(userId=223, movieId=1342, prediction=2.744095802307129)
# Row(userId=387, movieId=1342, prediction=2.272521495819092)
# Row(userId=597, movieId=1580, prediction=3.4817399978637695)
# Row(userId=34, movieId=1580, prediction=3.1108264923095703)
# Row(userId=368, movieId=1580, prediction=2.9642958641052246)
# Row(userId=28, movieId=1580, prediction=2.3493292331695557)
# Row(userId=183, movieId=1580, prediction=3.4703447818756104)
# Row(userId=587, movieId=1580, prediction=4.023591995239258)
# Row(userId=27, movieId=1580, prediction=3.77427077293396)
# Row(userId=330, movieId=1580, prediction=2.8648035526275635)
# Row(userId=230, movieId=1580, prediction=2.8536288738250732)
# Row(userId=233, movieId=1580, prediction=2.6823320388793945)
# Row(userId=47, movieId=1580, prediction=2.5734455585479736)
# Row(userId=1, movieId=1580, prediction=4.3051605224609375)
# Row(userId=274, movieId=1580, prediction=3.207746982574463)
# Row(userId=280, movieId=1580, prediction=3.398146390914917)
# Row(userId=169, movieId=1580, prediction=4.15037202835083)
# Row(userId=500, movieId=1580, prediction=2.4592058658599854)
# Row(userId=266, movieId=1580, prediction=2.941606044769287)
# Row(userId=19, movieId=1580, prediction=2.8836214542388916)
# Row(userId=542, movieId=1580, prediction=4.081335067749023)
# Row(userId=560, movieId=1580, prediction=3.1509547233581543)
# Row(userId=607, movieId=1580, prediction=3.49101185798645)
# Row(userId=590, movieId=1580, prediction=3.0345301628112793)
# Row(userId=202, movieId=1580, prediction=3.5794897079467773)
# Row(userId=263, movieId=1580, prediction=3.381765365600586)
# Row(userId=286, movieId=1580, prediction=3.3128669261932373)
# Row(userId=381, movieId=1580, prediction=3.192033290863037)
# Row(userId=4, movieId=1580, prediction=3.438483238220215)
# Row(userId=555, movieId=1580, prediction=3.644266128540039)
# Row(userId=453, movieId=1580, prediction=4.092342376708984)
# Row(userId=434, movieId=1580, prediction=2.920341730117798)
# Row(userId=438, movieId=1580, prediction=3.557791233062744)
# Row(userId=532, movieId=1580, prediction=3.937486171722412)
# Row(userId=69, movieId=1580, prediction=3.899430513381958)
# Row(userId=239, movieId=1580, prediction=3.579972743988037)
# Row(userId=361, movieId=1580, prediction=2.8730621337890625)
# Row(userId=50, movieId=1580, prediction=2.0538759231567383)
# Row(userId=288, movieId=1580, prediction=3.1481263637542725)
# Row(userId=160, movieId=1580, prediction=2.166256904602051)
# Row(userId=125, movieId=1580, prediction=3.3250036239624023)
# Row(userId=477, movieId=1580, prediction=3.1125965118408203)
# Row(userId=226, movieId=1580, prediction=3.3152623176574707)
# Row(userId=21, movieId=1580, prediction=3.235365390777588)
# Row(userId=265, movieId=1580, prediction=3.6805453300476074)
# Row(userId=608, movieId=1580, prediction=2.784684896469116)
# Row(userId=200, movieId=1580, prediction=3.6381616592407227)
# Row(userId=534, movieId=1580, prediction=3.5802197456359863)
# Row(userId=354, movieId=1580, prediction=3.4886651039123535)
# Row(userId=33, movieId=1580, prediction=3.1356277465820312)
# Row(userId=198, movieId=1580, prediction=3.238884210586548)
# Row(userId=79, movieId=1580, prediction=3.9141013622283936)
# Row(userId=201, movieId=1580, prediction=4.279970169067383)
# Row(userId=282, movieId=1580, prediction=3.657841682434082)
# Row(userId=18, movieId=1580, prediction=3.2811410427093506)
# Row(userId=104, movieId=1580, prediction=3.4283316135406494)
# Row(userId=483, movieId=1580, prediction=3.1637163162231445)
# Row(userId=362, movieId=1591, prediction=2.798354148864746)
# Row(userId=19, movieId=1591, prediction=2.1563427448272705)
# Row(userId=438, movieId=1591, prediction=2.4914374351501465)
# Row(userId=448, movieId=1591, prediction=2.307852029800415)
# Row(userId=464, movieId=1591, prediction=2.803539276123047)
# Row(userId=198, movieId=1591, prediction=2.877000570297241)
# Row(userId=368, movieId=1645, prediction=2.867217540740967)
# Row(userId=28, movieId=1645, prediction=2.472801685333252)
# Row(userId=297, movieId=1645, prediction=2.8240556716918945)
# Row(userId=432, movieId=1645, prediction=2.929517984390259)
# Row(userId=19, movieId=1645, prediction=2.832113265991211)
# Row(userId=309, movieId=1645, prediction=2.5849437713623047)
# Row(userId=586, movieId=1645, prediction=3.982651472091675)
# Row(userId=307, movieId=1645, prediction=2.6079933643341064)
# Row(userId=51, movieId=1645, prediction=3.66147780418396)
# Row(userId=354, movieId=1645, prediction=3.3693666458129883)
# Row(userId=198, movieId=1645, prediction=3.1350550651550293)
# Row(userId=282, movieId=1645, prediction=3.5702149868011475)
# Row(userId=577, movieId=1959, prediction=3.5891916751861572)
# Row(userId=384, movieId=1959, prediction=3.041468620300293)
# Row(userId=606, movieId=1959, prediction=3.5336973667144775)
# Row(userId=603, movieId=1959, prediction=3.900852680206299)
# Row(userId=342, movieId=1959, prediction=2.739025592803955)
# Row(userId=474, movieId=2122, prediction=1.8143013715744019)
# Row(userId=307, movieId=2122, prediction=2.3620095252990723)
# Row(userId=387, movieId=2142, prediction=1.899119257926941)
# Row(userId=600, movieId=2142, prediction=2.347227096557617)
# Row(userId=599, movieId=2366, prediction=2.7103211879730225)
# Row(userId=177, movieId=2366, prediction=3.627624034881592)
# Row(userId=325, movieId=2366, prediction=3.5681772232055664)
# Row(userId=1, movieId=2366, prediction=4.483147144317627)
# Row(userId=527, movieId=2366, prediction=4.073124885559082)
# Row(userId=70, movieId=2366, prediction=3.813723087310791)
# Row(userId=508, movieId=2366, prediction=2.3477747440338135)
# Row(userId=313, movieId=2366, prediction=3.8743600845336914)
# Row(userId=603, movieId=2866, prediction=2.822857141494751)
# Row(userId=462, movieId=2866, prediction=2.1676394939422607)
# Row(userId=288, movieId=2866, prediction=2.9527950286865234)
# Row(userId=101, movieId=3175, prediction=3.30991792678833)
# Row(userId=409, movieId=3175, prediction=3.3108065128326416)
# Row(userId=599, movieId=3175, prediction=2.5593390464782715)
# Row(userId=111, movieId=3175, prediction=2.8881564140319824)
# Row(userId=355, movieId=3175, prediction=3.3628993034362793)
# Row(userId=325, movieId=3175, prediction=3.2205758094787598)
# Row(userId=274, movieId=3175, prediction=3.1432082653045654)
# Row(userId=328, movieId=3175, prediction=3.2862677574157715)
# Row(userId=500, movieId=3175, prediction=2.8776681423187256)
# Row(userId=292, movieId=3175, prediction=2.982789993286133)
# Row(userId=96, movieId=3175, prediction=3.7803866863250732)
# Row(userId=452, movieId=3175, prediction=4.256035327911377)
# Row(userId=489, movieId=3175, prediction=2.5168471336364746)
# Row(userId=590, movieId=3175, prediction=3.129836082458496)
# Row(userId=586, movieId=3175, prediction=3.557166814804077)
# Row(userId=555, movieId=3175, prediction=3.514265775680542)
# Row(userId=428, movieId=3175, prediction=2.31169056892395)
# Row(userId=391, movieId=3175, prediction=3.1282691955566406)
# Row(userId=69, movieId=3175, prediction=3.880035638809204)
# Row(userId=234, movieId=3175, prediction=3.631343126296997)
# Row(userId=167, movieId=3175, prediction=3.2616186141967773)
# Row(userId=219, movieId=3175, prediction=3.1907267570495605)
# Row(userId=141, movieId=3175, prediction=3.0686864852905273)
# Row(userId=304, movieId=3175, prediction=3.6387083530426025)
# Row(userId=186, movieId=3175, prediction=3.9082016944885254)
# Row(userId=275, movieId=3175, prediction=3.3445851802825928)
# Row(userId=387, movieId=3918, prediction=3.4423887729644775)
# Row(userId=288, movieId=3918, prediction=3.1535630226135254)
# Row(userId=34, movieId=3997, prediction=1.244455099105835)
# Row(userId=599, movieId=3997, prediction=1.5817586183547974)
# Row(userId=177, movieId=3997, prediction=2.6689703464508057)
# Row(userId=605, movieId=3997, prediction=2.0373635292053223)
# Row(userId=274, movieId=4519, prediction=2.8354058265686035)
# Row(userId=318, movieId=4519, prediction=3.187535285949707)
# Row(userId=438, movieId=5803, prediction=1.8264203071594238)
# Row(userId=448, movieId=5803, prediction=1.6645015478134155)
# Row(userId=82, movieId=5803, prediction=1.7735234498977661)
# Row(userId=275, movieId=5803, prediction=2.768401861190796)
# Row(userId=91, movieId=6620, prediction=3.2601490020751953)
# Row(userId=462, movieId=6620, prediction=3.301140308380127)
# Row(userId=287, movieId=6620, prediction=3.4153804779052734)
# Row(userId=448, movieId=6658, prediction=2.499035358428955)
# Row(userId=346, movieId=8638, prediction=3.263888120651245)
# Row(userId=599, movieId=8638, prediction=2.82029390335083)
# Row(userId=263, movieId=8638, prediction=3.852067232131958)
# Row(userId=241, movieId=8638, prediction=3.4314215183258057)
# Row(userId=414, movieId=8638, prediction=3.691110134124756)
# Row(userId=200, movieId=8638, prediction=4.009613990783691)
# Row(userId=105, movieId=8638, prediction=4.039685249328613)
# Row(userId=326, movieId=32460, prediction=3.0487613677978516)
# Row(userId=105, movieId=32460, prediction=3.2061002254486084)
# Row(userId=232, movieId=36525, prediction=1.9685572385787964)
# Row(userId=274, movieId=36525, prediction=2.4527382850646973)
# Row(userId=358, movieId=36525, prediction=1.6473933458328247)
# Row(userId=380, movieId=36525, prediction=2.9256770610809326)
# Row(userId=143, movieId=36525, prediction=1.1887683868408203)
# Row(userId=177, movieId=44022, prediction=3.166635036468506)
# Row(userId=475, movieId=44022, prediction=3.6279125213623047)
# Row(userId=274, movieId=54190, prediction=3.622102737426758)
# Row(userId=125, movieId=54190, prediction=3.8889317512512207)
# Row(userId=414, movieId=54190, prediction=3.8920400142669678)
# Row(userId=525, movieId=54190, prediction=3.6964194774627686)
# Row(userId=280, movieId=68135, prediction=3.2398979663848877)
# Row(userId=563, movieId=68135, prediction=2.7425403594970703)
# Row(userId=509, movieId=68135, prediction=2.502450704574585)
# Row(userId=105, movieId=96488, prediction=3.158820867538452)
# Row(userId=18, movieId=96488, prediction=3.1740574836730957)
# Row(userId=318, movieId=160563, prediction=2.578097343444824)
# Row(userId=408, movieId=160563, prediction=2.738006591796875)
# Row(userId=125, movieId=160563, prediction=2.564061403274536)
# Row(userId=365, movieId=160563, prediction=1.981621265411377)
# Row(userId=385, movieId=540, prediction=2.0625393390655518)
# Row(userId=6, movieId=540, prediction=3.1626269817352295)
# Row(userId=262, movieId=540, prediction=1.992139458656311)
# Row(userId=181, movieId=540, prediction=2.2351982593536377)
# Row(userId=411, movieId=540, prediction=2.541378974914551)
# Row(userId=414, movieId=540, prediction=2.6470279693603516)
# Row(userId=592, movieId=540, prediction=2.0598719120025635)
# Row(userId=109, movieId=540, prediction=2.3145313262939453)
# Row(userId=14, movieId=540, prediction=3.380652904510498)
# Row(userId=269, movieId=737, prediction=2.859132766723633)
# Row(userId=217, movieId=737, prediction=2.625377655029297)
# Row(userId=524, movieId=737, prediction=2.7555091381073)
# Row(userId=234, movieId=737, prediction=2.500525712966919)
# Row(userId=608, movieId=737, prediction=1.0080809593200684)
# Row(userId=137, movieId=858, prediction=4.03267240524292)
# Row(userId=472, movieId=858, prediction=4.103154182434082)
# Row(userId=593, movieId=858, prediction=3.5565547943115234)
# Row(userId=597, movieId=858, prediction=4.909542560577393)
# Row(userId=193, movieId=858, prediction=3.917635440826416)
# Row(userId=211, movieId=858, prediction=3.88488507270813)
# Row(userId=368, movieId=858, prediction=3.6448912620544434)
# Row(userId=76, movieId=858, prediction=2.9207541942596436)
# Row(userId=350, movieId=858, prediction=3.736487627029419)
# Row(userId=417, movieId=858, prediction=4.626842021942139)
# Row(userId=222, movieId=858, prediction=3.4304041862487793)
# Row(userId=122, movieId=858, prediction=5.050967693328857)
# Row(userId=190, movieId=858, prediction=4.271645545959473)
# Row(userId=232, movieId=858, prediction=3.6886508464813232)
# Row(userId=233, movieId=858, prediction=3.5631744861602783)
# Row(userId=599, movieId=858, prediction=3.256744623184204)
# Row(userId=152, movieId=858, prediction=4.126315593719482)
# Row(userId=305, movieId=858, prediction=4.313008785247803)
# Row(userId=603, movieId=858, prediction=4.156281471252441)
# Row(userId=182, movieId=858, prediction=4.180387496948242)
# Row(userId=348, movieId=858, prediction=4.985001087188721)
# Row(userId=168, movieId=858, prediction=4.480304718017578)
# Row(userId=308, movieId=858, prediction=1.5448346138000488)
# Row(userId=328, movieId=858, prediction=3.7721917629241943)
# Row(userId=295, movieId=858, prediction=3.9904305934906006)
# Row(userId=120, movieId=858, prediction=3.354060173034668)
# Row(userId=452, movieId=858, prediction=5.139970302581787)
# Row(userId=268, movieId=858, prediction=4.161734580993652)
# Row(userId=430, movieId=858, prediction=4.400141716003418)
# Row(userId=227, movieId=858, prediction=4.361189365386963)
# Row(userId=327, movieId=858, prediction=4.075977325439453)
# Row(userId=197, movieId=858, prediction=4.278388023376465)
# Row(userId=462, movieId=858, prediction=3.461730480194092)
# Row(userId=17, movieId=858, prediction=4.11904764175415)
# Row(userId=503, movieId=858, prediction=4.036938190460205)
# Row(userId=217, movieId=858, prediction=3.32171893119812)
# Row(userId=307, movieId=858, prediction=3.500460386276245)
# Row(userId=39, movieId=858, prediction=4.545217514038086)
# Row(userId=238, movieId=858, prediction=3.830984592437744)
# Row(userId=453, movieId=858, prediction=4.635899066925049)
# Row(userId=247, movieId=858, prediction=4.054299354553223)
# Row(userId=343, movieId=858, prediction=4.198968887329102)
# Row(userId=97, movieId=858, prediction=4.307276248931885)
# Row(userId=63, movieId=858, prediction=4.037259101867676)
# Row(userId=45, movieId=858, prediction=4.562511920928955)
# Row(userId=82, movieId=858, prediction=3.1378772258758545)
# Row(userId=510, movieId=858, prediction=3.2771718502044678)
# Row(userId=62, movieId=858, prediction=4.4029083251953125)
# Row(userId=125, movieId=858, prediction=4.342830657958984)
# Row(userId=156, movieId=858, prediction=4.107199668884277)
# Row(userId=219, movieId=858, prediction=3.820089817047119)
# Row(userId=21, movieId=858, prediction=2.8632240295410156)
# Row(userId=338, movieId=858, prediction=4.009157657623291)
# Row(userId=492, movieId=858, prediction=4.5991106033325195)
# Row(userId=469, movieId=858, prediction=4.492518901824951)
# Row(userId=414, movieId=858, prediction=4.427441596984863)
# Row(userId=68, movieId=858, prediction=3.278597593307495)
# Row(userId=199, movieId=858, prediction=3.902437448501587)
# Row(userId=79, movieId=858, prediction=4.5892558097839355)
# Row(userId=131, movieId=858, prediction=3.531409502029419)
# Row(userId=118, movieId=858, prediction=4.1775288581848145)
# Row(userId=573, movieId=858, prediction=4.244100093841553)
# Row(userId=275, movieId=858, prediction=4.694809913635254)
# Row(userId=18, movieId=858, prediction=4.038210868835449)
# Row(userId=483, movieId=858, prediction=4.204751968383789)
# Row(userId=57, movieId=897, prediction=2.803372859954834)
# Row(userId=211, movieId=1025, prediction=3.4614145755767822)
# Row(userId=474, movieId=1025, prediction=3.3250672817230225)
# Row(userId=328, movieId=1025, prediction=3.1279478073120117)
# Row(userId=20, movieId=1025, prediction=3.8140034675598145)
# Row(userId=387, movieId=1025, prediction=2.8624980449676514)
# Row(userId=4, movieId=1025, prediction=3.4624745845794678)
# Row(userId=39, movieId=1025, prediction=3.681088924407959)
# Row(userId=509, movieId=1025, prediction=3.1400516033172607)
# Row(userId=288, movieId=1025, prediction=3.283550262451172)
# Row(userId=414, movieId=1025, prediction=3.6792240142822266)
# Row(userId=517, movieId=1025, prediction=2.462949752807617)
# Row(userId=599, movieId=1084, prediction=2.9383480548858643)
# Row(userId=607, movieId=1084, prediction=3.6781742572784424)
# Row(userId=63, movieId=1084, prediction=3.945525646209717)
# Row(userId=589, movieId=1084, prediction=4.797065258026123)
# Row(userId=181, movieId=1084, prediction=2.874563217163086)
# Row(userId=288, movieId=1084, prediction=3.4750120639801025)
# Row(userId=156, movieId=1084, prediction=3.9293715953826904)
# Row(userId=294, movieId=1084, prediction=3.55985689163208)
# Row(userId=357, movieId=1084, prediction=3.7127325534820557)
# Row(userId=275, movieId=1084, prediction=3.924776315689087)
# Row(userId=410, movieId=1084, prediction=3.9074792861938477)
# Row(userId=392, movieId=1127, prediction=3.076946973800659)
# Row(userId=368, movieId=1127, prediction=2.886040210723877)
# Row(userId=577, movieId=1127, prediction=3.3016295433044434)
# Row(userId=57, movieId=1127, prediction=3.313405990600586)
# Row(userId=610, movieId=1127, prediction=3.5034403800964355)
# Row(userId=428, movieId=1127, prediction=2.5842716693878174)
# Row(userId=312, movieId=1127, prediction=3.4475150108337402)
# Row(userId=82, movieId=1127, prediction=3.1192150115966797)
# Row(userId=591, movieId=1127, prediction=3.3138110637664795)
# Row(userId=480, movieId=1127, prediction=2.9319076538085938)
# Row(userId=477, movieId=1127, prediction=3.4171254634857178)
# Row(userId=303, movieId=1127, prediction=3.8353395462036133)
# Row(userId=298, movieId=1127, prediction=2.3135862350463867)
# Row(userId=600, movieId=1127, prediction=2.7582476139068604)
# Row(userId=79, movieId=1127, prediction=3.7104790210723877)
# Row(userId=294, movieId=1127, prediction=2.5075974464416504)
# Row(userId=313, movieId=1127, prediction=3.187011957168579)
# Row(userId=84, movieId=1395, prediction=2.673452854156494)
# Row(userId=481, movieId=1483, prediction=2.1218934059143066)
# Row(userId=297, movieId=1483, prediction=3.9719483852386475)
# Row(userId=387, movieId=1483, prediction=3.459704637527466)
# Row(userId=326, movieId=1483, prediction=3.9500412940979004)
# Row(userId=135, movieId=1483, prediction=3.942795753479004)
# Row(userId=481, movieId=1721, prediction=3.198084831237793)
# Row(userId=322, movieId=1721, prediction=3.0967252254486084)
# Row(userId=115, movieId=1721, prediction=3.8440322875976562)
# Row(userId=27, movieId=1721, prediction=3.5855226516723633)
# Row(userId=601, movieId=1721, prediction=3.692018985748291)
# Row(userId=230, movieId=1721, prediction=1.9210054874420166)
# Row(userId=93, movieId=1721, prediction=4.117731094360352)
# Row(userId=224, movieId=1721, prediction=5.097727298736572)
# Row(userId=47, movieId=1721, prediction=3.1515328884124756)
# Row(userId=140, movieId=1721, prediction=3.6961188316345215)
# Row(userId=274, movieId=1721, prediction=2.559473752975464)
# Row(userId=13, movieId=1721, prediction=3.3662822246551514)
# Row(userId=280, movieId=1721, prediction=3.970945119857788)
# Row(userId=169, movieId=1721, prediction=4.074997901916504)
# Row(userId=57, movieId=1721, prediction=2.949718713760376)
# Row(userId=292, movieId=1721, prediction=3.248095989227295)
# Row(userId=339, movieId=1721, prediction=3.370450019836426)
# Row(userId=96, movieId=1721, prediction=4.059565544128418)
# Row(userId=542, movieId=1721, prediction=2.940103530883789)
# Row(userId=425, movieId=1721, prediction=3.087397813796997)
# Row(userId=495, movieId=1721, prediction=3.2595715522766113)
# Row(userId=532, movieId=1721, prediction=3.9456465244293213)
# Row(userId=69, movieId=1721, prediction=4.0332841873168945)
# Row(userId=361, movieId=1721, prediction=2.4720847606658936)
# Row(userId=288, movieId=1721, prediction=2.865319013595581)
# Row(userId=480, movieId=1721, prediction=3.2689223289489746)
# Row(userId=143, movieId=1721, prediction=3.7049219608306885)
# Row(userId=219, movieId=1721, prediction=2.148343086242676)
# Row(userId=352, movieId=1721, prediction=3.0459351539611816)
# Row(userId=490, movieId=1721, prediction=2.4158873558044434)
# Row(userId=382, movieId=1721, prediction=3.54716157913208)
# Row(userId=608, movieId=1721, prediction=2.9544382095336914)
# Row(userId=200, movieId=1721, prediction=3.6518869400024414)
# Row(userId=272, movieId=1721, prediction=3.05397891998291)
# Row(userId=354, movieId=1721, prediction=3.139145612716675)
# Row(userId=304, movieId=1721, prediction=3.7991058826446533)
# Row(userId=369, movieId=1721, prediction=2.1542513370513916)
# Row(userId=116, movieId=1721, prediction=2.9344189167022705)
# Row(userId=135, movieId=1721, prediction=2.9007744789123535)
# Row(userId=357, movieId=1721, prediction=3.6160852909088135)
# Row(userId=282, movieId=1721, prediction=3.298536777496338)
# Row(userId=551, movieId=1721, prediction=3.1539039611816406)
# Row(userId=420, movieId=1721, prediction=3.238312244415283)
# Row(userId=18, movieId=1721, prediction=3.192359209060669)
# Row(userId=483, movieId=1721, prediction=2.945704698562622)
# Row(userId=517, movieId=1721, prediction=2.4039082527160645)
# Row(userId=597, movieId=2387, prediction=4.110551357269287)
# Row(userId=606, movieId=2387, prediction=3.2275660037994385)
# Row(userId=19, movieId=2387, prediction=2.412862539291382)
# Row(userId=135, movieId=2387, prediction=3.7182369232177734)
# Row(userId=294, movieId=2387, prediction=2.934951066970825)
# Row(userId=599, movieId=2580, prediction=2.879972219467163)
# Row(userId=603, movieId=2580, prediction=3.2048017978668213)
# Row(userId=1, movieId=2580, prediction=4.472416877746582)
# Row(userId=268, movieId=2580, prediction=3.1417789459228516)
# Row(userId=55, movieId=2580, prediction=4.200641632080078)
# Row(userId=576, movieId=2580, prediction=2.2597293853759766)
# Row(userId=480, movieId=2580, prediction=3.5049734115600586)
# Row(userId=260, movieId=2580, prediction=3.4128634929656982)
# Row(userId=42, movieId=2580, prediction=3.939908504486084)
# Row(userId=101, movieId=3179, prediction=3.4421448707580566)
# Row(userId=603, movieId=3475, prediction=4.186923503875732)
# Row(userId=580, movieId=3698, prediction=2.638143539428711)
# Row(userId=325, movieId=3698, prediction=3.225672483444214)
# Row(userId=452, movieId=3698, prediction=4.0731892585754395)
# Row(userId=425, movieId=3698, prediction=2.833982229232788)
# Row(userId=391, movieId=3698, prediction=3.2086329460144043)
# Row(userId=448, movieId=3698, prediction=3.2911951541900635)
# Row(userId=527, movieId=3698, prediction=3.644061803817749)
# Row(userId=469, movieId=3698, prediction=3.384591817855835)
# Row(userId=414, movieId=3698, prediction=3.448333263397217)
# Row(userId=68, movieId=3698, prediction=2.6952757835388184)
# Row(userId=561, movieId=3698, prediction=3.065861463546753)
# Row(userId=294, movieId=3698, prediction=2.873096466064453)
# Row(userId=66, movieId=4158, prediction=1.8809473514556885)
# Row(userId=20, movieId=4161, prediction=2.96983003616333)
# Row(userId=608, movieId=4161, prediction=3.336829900741577)
# Row(userId=200, movieId=4161, prediction=3.6985952854156494)
# Row(userId=68, movieId=4161, prediction=3.153080940246582)
# Row(userId=422, movieId=4190, prediction=3.807274341583252)
# Row(userId=414, movieId=4219, prediction=2.5731968879699707)
# Row(userId=562, movieId=4219, prediction=2.878023862838745)
# Row(userId=45, movieId=4929, prediction=2.4442050457000732)
# Row(userId=387, movieId=6773, prediction=3.1218655109405518)
# Row(userId=50, movieId=6773, prediction=2.624251365661621)
# Row(userId=480, movieId=6773, prediction=3.2423746585845947)
# Row(userId=414, movieId=6773, prediction=3.8012232780456543)
# Row(userId=488, movieId=6773, prediction=3.2406797409057617)
# Row(userId=260, movieId=6773, prediction=3.1496310234069824)
# Row(userId=50, movieId=8928, prediction=3.0366313457489014)
# Row(userId=596, movieId=48780, prediction=3.417236328125)
# Row(userId=332, movieId=48780, prediction=3.5027592182159424)
# Row(userId=103, movieId=48780, prediction=4.135130882263184)
# Row(userId=460, movieId=48780, prediction=3.970531463623047)
# Row(userId=233, movieId=48780, prediction=3.228926181793213)
# Row(userId=132, movieId=48780, prediction=3.073120355606079)
# Row(userId=474, movieId=48780, prediction=3.4233930110931396)
# Row(userId=139, movieId=48780, prediction=1.811350703239441)
# Row(userId=570, movieId=48780, prediction=3.3025341033935547)
# Row(userId=279, movieId=48780, prediction=3.548100709915161)
# Row(userId=309, movieId=48780, prediction=3.3788204193115234)
# Row(userId=15, movieId=48780, prediction=3.348548173904419)
# Row(userId=301, movieId=48780, prediction=3.454408884048462)
# Row(userId=261, movieId=48780, prediction=3.8111443519592285)
# Row(userId=288, movieId=48780, prediction=3.507017135620117)
# Row(userId=80, movieId=48780, prediction=4.1930389404296875)
# Row(userId=351, movieId=48780, prediction=3.504088878631592)
# Row(userId=477, movieId=48780, prediction=3.994333505630493)
# Row(userId=414, movieId=48780, prediction=3.9877936840057373)
# Row(userId=254, movieId=48780, prediction=3.8852858543395996)
# Row(userId=204, movieId=48780, prediction=4.027399063110352)
# Row(userId=68, movieId=48780, prediction=3.082252264022827)
# Row(userId=567, movieId=48780, prediction=2.4191365242004395)
# Row(userId=561, movieId=48780, prediction=3.4846348762512207)
# Row(userId=424, movieId=48780, prediction=3.4207239151000977)
# Row(userId=123, movieId=48780, prediction=3.595262050628662)
# Row(userId=573, movieId=48780, prediction=3.9907355308532715)
# Row(userId=104, movieId=48780, prediction=3.467221260070801)
# Row(userId=517, movieId=56941, prediction=2.2866382598876953)
# Row(userId=122, movieId=69481, prediction=4.765096664428711)
# Row(userId=177, movieId=69481, prediction=3.5402235984802246)
# Row(userId=52, movieId=69481, prediction=4.386387825012207)
# Row(userId=432, movieId=69481, prediction=3.374293804168701)
# Row(userId=339, movieId=69481, prediction=4.254494667053223)
# Row(userId=448, movieId=69481, prediction=3.5911381244659424)
# Row(userId=63, movieId=69481, prediction=3.7850282192230225)
# Row(userId=414, movieId=69481, prediction=4.144840717315674)
# Row(userId=317, movieId=69481, prediction=3.987220287322998)
# Row(userId=434, movieId=74452, prediction=0.0)
# Row(userId=318, movieId=101362, prediction=2.6459810733795166)
# Row(userId=62, movieId=166635, prediction=3.9765305519104004)
# Row(userId=125, movieId=166635, prediction=3.7690696716308594)
# Row(userId=372, movieId=31, prediction=3.165112257003784)
# Row(userId=599, movieId=31, prediction=2.073275089263916)
# Row(userId=6, movieId=31, prediction=3.8622970581054688)
# Row(userId=387, movieId=31, prediction=2.0182206630706787)
# Row(userId=181, movieId=31, prediction=3.4316248893737793)
# Row(userId=411, movieId=31, prediction=3.5556716918945312)
# Row(userId=464, movieId=31, prediction=3.0347602367401123)
# Row(userId=203, movieId=31, prediction=2.995842218399048)
# Row(userId=282, movieId=31, prediction=3.1749136447906494)
# Row(userId=436, movieId=516, prediction=3.173764228820801)
# Row(userId=599, movieId=516, prediction=2.040562868118286)
# Row(userId=474, movieId=516, prediction=2.8722198009490967)
# Row(userId=181, movieId=516, prediction=3.0442869663238525)
# Row(userId=477, movieId=516, prediction=2.494107246398926)
# Row(userId=109, movieId=516, prediction=2.9967758655548096)
# Row(userId=536, movieId=516, prediction=3.815086603164673)
# Row(userId=66, movieId=516, prediction=2.931455135345459)
# Row(userId=78, movieId=1270, prediction=3.654278516769409)
# Row(userId=108, movieId=1270, prediction=4.199116230010986)
# Row(userId=385, movieId=1270, prediction=3.7370715141296387)
# Row(userId=587, movieId=1270, prediction=4.466004371643066)
# Row(userId=27, movieId=1270, prediction=4.038328647613525)
# Row(userId=91, movieId=1270, prediction=3.576322555541992)
# Row(userId=157, movieId=1270, prediction=4.034426689147949)
# Row(userId=224, movieId=1270, prediction=4.202023983001709)
# Row(userId=305, movieId=1270, prediction=3.9488754272460938)
# Row(userId=325, movieId=1270, prediction=3.565370559692383)
# Row(userId=280, movieId=1270, prediction=3.994511365890503)
# Row(userId=178, movieId=1270, prediction=3.8654494285583496)
# Row(userId=328, movieId=1270, prediction=3.2190561294555664)
# Row(userId=169, movieId=1270, prediction=4.636699199676514)
# Row(userId=570, movieId=1270, prediction=3.435375452041626)
# Row(userId=339, movieId=1270, prediction=3.86818790435791)
# Row(userId=19, movieId=1270, prediction=3.257972002029419)
# Row(userId=607, movieId=1270, prediction=4.1686553955078125)
# Row(userId=15, movieId=1270, prediction=3.4174392223358154)
# Row(userId=489, movieId=1270, prediction=3.0482115745544434)
# Row(userId=318, movieId=1270, prediction=3.659895896911621)
# Row(userId=231, movieId=1270, prediction=3.546319007873535)
# Row(userId=381, movieId=1270, prediction=3.7674686908721924)
# Row(userId=437, movieId=1270, prediction=4.050297737121582)
# Row(userId=39, movieId=1270, prediction=4.106083393096924)
# Row(userId=7, movieId=1270, prediction=3.685481071472168)
# Row(userId=514, movieId=1270, prediction=3.724777936935425)
# Row(userId=171, movieId=1270, prediction=4.806044101715088)
# Row(userId=400, movieId=1270, prediction=4.051710605621338)
# Row(userId=249, movieId=1270, prediction=4.044543743133545)
# Row(userId=356, movieId=1270, prediction=4.007612228393555)
# Row(userId=70, movieId=1270, prediction=3.9342243671417236)
# Row(userId=62, movieId=1270, prediction=4.165730953216553)
# Row(userId=95, movieId=1270, prediction=4.374653339385986)
# Row(userId=477, movieId=1270, prediction=3.765505790710449)
# Row(userId=29, movieId=1270, prediction=3.962908983230591)
# Row(userId=256, movieId=1270, prediction=4.207325458526611)
# Row(userId=457, movieId=1270, prediction=4.098767280578613)
# Row(userId=334, movieId=1270, prediction=3.256748676300049)
# Row(userId=200, movieId=1270, prediction=4.129724025726318)
# Row(userId=376, movieId=1270, prediction=4.116369247436523)
# Row(userId=303, movieId=1270, prediction=4.433382987976074)
# Row(userId=354, movieId=1270, prediction=3.8957512378692627)
# Row(userId=304, movieId=1270, prediction=4.330574989318848)
# Row(userId=68, movieId=1270, prediction=3.4812448024749756)
# Row(userId=525, movieId=1270, prediction=3.55674147605896)
# Row(userId=116, movieId=1270, prediction=3.366755723953247)
# Row(userId=42, movieId=1270, prediction=4.263091564178467)
# Row(userId=149, movieId=1270, prediction=3.193081855773926)
# Row(userId=276, movieId=1270, prediction=4.8887248039245605)
# Row(userId=66, movieId=1270, prediction=4.0692596435546875)
# Row(userId=275, movieId=1270, prediction=4.035461902618408)
# Row(userId=282, movieId=1270, prediction=4.081539154052734)
# Row(userId=551, movieId=1270, prediction=3.7547829151153564)
# Row(userId=475, movieId=1270, prediction=4.509105205535889)
# Row(userId=517, movieId=1270, prediction=2.579296350479126)
# Row(userId=332, movieId=1303, prediction=3.5961618423461914)
# Row(userId=325, movieId=1303, prediction=3.674654006958008)
# Row(userId=474, movieId=1303, prediction=3.4462385177612305)
# Row(userId=57, movieId=1303, prediction=4.0782952308654785)
# Row(userId=268, movieId=1303, prediction=3.381150960922241)
# Row(userId=387, movieId=1303, prediction=3.4909229278564453)
# Row(userId=70, movieId=1303, prediction=3.9237725734710693)
# Row(userId=469, movieId=1303, prediction=4.0857319831848145)
# Row(userId=19, movieId=1322, prediction=0.0)
# Row(userId=571, movieId=1322, prediction=0.0)
# Row(userId=580, movieId=1339, prediction=2.422128200531006)
# Row(userId=346, movieId=1339, prediction=3.3795032501220703)
# Row(userId=19, movieId=1339, prediction=2.63783597946167)
# Row(userId=387, movieId=1339, prediction=3.1581761837005615)
# Row(userId=380, movieId=1339, prediction=3.114581823348999)
# Row(userId=116, movieId=1339, prediction=2.0637550354003906)
# Row(userId=42, movieId=1339, prediction=3.1334359645843506)
# Row(userId=599, movieId=1352, prediction=1.4445886611938477)
# Row(userId=603, movieId=1699, prediction=2.810805082321167)
# Row(userId=137, movieId=2393, prediction=2.032135009765625)
# Row(userId=587, movieId=2393, prediction=3.5010533332824707)
# Row(userId=57, movieId=2393, prediction=2.4186596870422363)
# Row(userId=452, movieId=2393, prediction=3.663754940032959)
# Row(userId=19, movieId=2393, prediction=2.4352004528045654)
# Row(userId=217, movieId=2393, prediction=3.0923328399658203)
# Row(userId=448, movieId=2393, prediction=3.1714539527893066)
# Row(userId=352, movieId=2393, prediction=2.708608865737915)
# Row(userId=469, movieId=2393, prediction=2.43306565284729)
# Row(userId=304, movieId=2393, prediction=3.517522096633911)
# Row(userId=131, movieId=2393, prediction=2.5283963680267334)
# Row(userId=325, movieId=2572, prediction=3.232483386993408)
# Row(userId=603, movieId=2572, prediction=3.6710867881774902)
# Row(userId=182, movieId=2572, prediction=3.272186756134033)
# Row(userId=280, movieId=2572, prediction=4.125366687774658)
# Row(userId=500, movieId=2572, prediction=2.6314873695373535)
# Row(userId=432, movieId=2572, prediction=3.7335662841796875)
# Row(userId=19, movieId=2572, prediction=2.8788485527038574)
# Row(userId=358, movieId=2572, prediction=4.376125812530518)
# Row(userId=489, movieId=2572, prediction=3.290038585662842)
# Row(userId=286, movieId=2572, prediction=3.26225209236145)
# Row(userId=307, movieId=2572, prediction=2.313537359237671)
# Row(userId=453, movieId=2572, prediction=3.6221084594726562)
# Row(userId=249, movieId=2572, prediction=3.557004928588867)
# Row(userId=480, movieId=2572, prediction=3.3038620948791504)
# Row(userId=354, movieId=2572, prediction=3.5574374198913574)
# Row(userId=260, movieId=2572, prediction=3.068495035171509)
# Row(userId=198, movieId=2572, prediction=3.751641273498535)
# Row(userId=365, movieId=2572, prediction=2.491701126098633)
# Row(userId=140, movieId=2996, prediction=2.576221227645874)
# Row(userId=383, movieId=2996, prediction=2.9906487464904785)
# Row(userId=599, movieId=3000, prediction=3.230229377746582)
# Row(userId=182, movieId=3000, prediction=4.13640832901001)
# Row(userId=489, movieId=3000, prediction=3.4251534938812256)
# Row(userId=318, movieId=3000, prediction=3.9067299365997314)
# Row(userId=387, movieId=3000, prediction=3.8092992305755615)
# Row(userId=39, movieId=3000, prediction=4.449175834655762)
# Row(userId=343, movieId=3000, prediction=3.939650297164917)
# Row(userId=428, movieId=3000, prediction=3.2904844284057617)
# Row(userId=166, movieId=3000, prediction=4.115062713623047)
# Row(userId=63, movieId=3000, prediction=4.022250175476074)
# Row(userId=480, movieId=3000, prediction=3.9227616786956787)
# Row(userId=260, movieId=3000, prediction=3.9477016925811768)
# Row(userId=483, movieId=3000, prediction=4.192780494689941)
# Row(userId=274, movieId=3213, prediction=3.609901189804077)
# Row(userId=19, movieId=3213, prediction=3.3759307861328125)
# Row(userId=39, movieId=3213, prediction=4.5113301277160645)
# Row(userId=166, movieId=3213, prediction=4.150907039642334)
# Row(userId=288, movieId=3213, prediction=3.741476535797119)
# Row(userId=477, movieId=3213, prediction=4.30478048324585)
# Row(userId=91, movieId=3704, prediction=2.933734178543091)
# Row(userId=380, movieId=3704, prediction=3.2822022438049316)
# Row(userId=313, movieId=3704, prediction=3.207380533218384)
# Row(userId=103, movieId=4489, prediction=3.4286460876464844)
# Row(userId=367, movieId=4489, prediction=3.527578115463257)
# Row(userId=479, movieId=4489, prediction=3.3157975673675537)
# Row(userId=167, movieId=4489, prediction=3.256321430206299)
# Row(userId=480, movieId=4489, prediction=2.6638588905334473)
# Row(userId=68, movieId=4489, prediction=3.018115282058716)
# Row(userId=42, movieId=4489, prediction=3.869870901107788)
# Row(userId=169, movieId=6266, prediction=3.2336435317993164)
# Row(userId=563, movieId=6266, prediction=2.4270031452178955)
# Row(userId=438, movieId=6266, prediction=2.3252837657928467)
# Row(userId=509, movieId=6266, prediction=2.3583943843841553)
# Row(userId=82, movieId=6266, prediction=1.749205231666565)
# Row(userId=111, movieId=6482, prediction=1.1097232103347778)
# Row(userId=307, movieId=6559, prediction=1.558741807937622)
# Row(userId=91, movieId=7387, prediction=3.8080389499664307)
# Row(userId=346, movieId=7387, prediction=3.2501654624938965)
# Row(userId=305, movieId=7387, prediction=4.2004194259643555)
# Row(userId=441, movieId=7387, prediction=4.299337387084961)
# Row(userId=83, movieId=7387, prediction=3.7255337238311768)
# Row(userId=260, movieId=7387, prediction=3.376187801361084)
# Row(userId=187, movieId=7387, prediction=3.2585604190826416)
# Row(userId=560, movieId=27266, prediction=3.4184553623199463)
# Row(userId=64, movieId=27266, prediction=3.8297173976898193)
# Row(userId=405, movieId=27266, prediction=3.5416059494018555)
# Row(userId=414, movieId=55272, prediction=3.66845440864563)
# Row(userId=318, movieId=55363, prediction=3.5961344242095947)
# Row(userId=249, movieId=55363, prediction=3.9177417755126953)
# Row(userId=563, movieId=61250, prediction=2.6321732997894287)
# Row(userId=10, movieId=61250, prediction=2.6585867404937744)
# Row(userId=143, movieId=61250, prediction=2.797069549560547)
# Row(userId=298, movieId=61250, prediction=1.2441695928573608)
# Row(userId=41, movieId=80906, prediction=3.9935264587402344)
# Row(userId=462, movieId=80906, prediction=2.2794318199157715)
# Row(userId=317, movieId=80906, prediction=4.066293716430664)
# Row(userId=596, movieId=82459, prediction=3.6441309452056885)
# Row(userId=435, movieId=82459, prediction=4.54199743270874)
# Row(userId=328, movieId=82459, prediction=3.129765033721924)
# Row(userId=339, movieId=82459, prediction=4.217886447906494)
# Row(userId=560, movieId=82459, prediction=3.7444427013397217)
# Row(userId=514, movieId=82459, prediction=3.8250138759613037)
# Row(userId=448, movieId=82459, prediction=3.645611524581909)
# Row(userId=249, movieId=82459, prediction=4.196942329406738)
# Row(userId=317, movieId=82459, prediction=3.828735113143921)
# Row(userId=522, movieId=82459, prediction=3.839571952819824)
# Row(userId=119, movieId=82459, prediction=4.429633140563965)
# Row(userId=517, movieId=82459, prediction=2.2406997680664062)
# Row(userId=382, movieId=135137, prediction=3.10532283782959)
# Row(userId=567, movieId=135137, prediction=1.3986185789108276)
# Row(userId=414, movieId=176751, prediction=4.076382160186768)
# Row(userId=191, movieId=85, prediction=4.698868751525879)
# Row(userId=414, movieId=251, prediction=2.320072889328003)
# Row(userId=599, movieId=580, prediction=2.321516513824463)
# Row(userId=593, movieId=1265, prediction=3.063821315765381)
# Row(userId=385, movieId=1265, prediction=3.8299033641815186)
# Row(userId=332, movieId=1265, prediction=3.5460915565490723)
# Row(userId=159, movieId=1265, prediction=2.8093714714050293)
# Row(userId=409, movieId=1265, prediction=3.933516502380371)
# Row(userId=330, movieId=1265, prediction=3.6611340045928955)
# Row(userId=539, movieId=1265, prediction=3.267369270324707)
# Row(userId=599, movieId=1265, prediction=2.99257755279541)
# Row(userId=140, movieId=1265, prediction=3.500943183898926)
# Row(userId=177, movieId=1265, prediction=3.41528058052063)
# Row(userId=474, movieId=1265, prediction=3.469177484512329)
# Row(userId=572, movieId=1265, prediction=4.211862087249756)
# Row(userId=178, movieId=1265, prediction=4.080361843109131)
# Row(userId=266, movieId=1265, prediction=4.135201454162598)
# Row(userId=41, movieId=1265, prediction=3.1165847778320312)
# Row(userId=318, movieId=1265, prediction=3.696427345275879)
# Row(userId=202, movieId=1265, prediction=4.078710079193115)
# Row(userId=387, movieId=1265, prediction=3.4087066650390625)
# Row(userId=610, movieId=1265, prediction=4.1045379638671875)
# Row(userId=241, movieId=1265, prediction=3.62266206741333)
# Row(userId=555, movieId=1265, prediction=4.092403888702393)
# Row(userId=380, movieId=1265, prediction=4.197778224945068)
# Row(userId=171, movieId=1265, prediction=4.737823009490967)
# Row(userId=166, movieId=1265, prediction=3.915562152862549)
# Row(userId=448, movieId=1265, prediction=3.626330614089966)
# Row(userId=63, movieId=1265, prediction=3.783595323562622)
# Row(userId=509, movieId=1265, prediction=3.3380348682403564)
# Row(userId=45, movieId=1265, prediction=4.304977893829346)
# Row(userId=510, movieId=1265, prediction=2.843162775039673)
# Row(userId=160, movieId=1265, prediction=3.5631790161132812)
# Row(userId=156, movieId=1265, prediction=3.6956896781921387)
# Row(userId=151, movieId=1265, prediction=3.831387996673584)
# Row(userId=414, movieId=1265, prediction=4.062193870544434)
# Row(userId=608, movieId=1265, prediction=3.3272759914398193)
# Row(userId=354, movieId=1265, prediction=3.7746164798736572)
# Row(userId=304, movieId=1265, prediction=3.9380953311920166)
# Row(userId=344, movieId=1265, prediction=3.7575793266296387)
# Row(userId=522, movieId=1265, prediction=3.702420711517334)
# Row(userId=313, movieId=1265, prediction=3.6469037532806396)
# Row(userId=282, movieId=1265, prediction=3.931246757507324)
# Row(userId=104, movieId=1265, prediction=3.518627405166626)
# Row(userId=187, movieId=1265, prediction=3.6753149032592773)
# Row(userId=517, movieId=1265, prediction=1.9314165115356445)
# Row(userId=76, movieId=1884, prediction=3.8696460723876953)
# Row(userId=606, movieId=1884, prediction=3.4681777954101562)
# Row(userId=182, movieId=1884, prediction=3.386462450027466)
# Row(userId=88, movieId=1884, prediction=4.051632404327393)
# Row(userId=610, movieId=1884, prediction=3.7147324085235596)
# Row(userId=249, movieId=1884, prediction=3.9242100715637207)
# Row(userId=73, movieId=1884, prediction=3.7708516120910645)
# Row(userId=226, movieId=1884, prediction=3.6992602348327637)
# Row(userId=414, movieId=1884, prediction=3.6093337535858154)
# Row(userId=298, movieId=1884, prediction=2.6718506813049316)
# Row(userId=68, movieId=1884, prediction=2.977850914001465)
# Row(userId=294, movieId=1884, prediction=2.484560966491699)
# Row(userId=282, movieId=1884, prediction=3.7274210453033447)
# Row(userId=514, movieId=1975, prediction=2.249300241470337)
# Row(userId=160, movieId=1975, prediction=1.9351038932800293)
# Row(userId=42, movieId=1975, prediction=1.968412160873413)
# Row(userId=182, movieId=2025, prediction=3.556241512298584)
# Row(userId=322, movieId=2231, prediction=3.435377597808838)
# Row(userId=606, movieId=2231, prediction=3.6394619941711426)
# Row(userId=103, movieId=2231, prediction=4.002925395965576)
# Row(userId=325, movieId=2231, prediction=3.4814693927764893)
# Row(userId=274, movieId=2231, prediction=3.6077775955200195)
# Row(userId=182, movieId=2231, prediction=3.425691604614258)
# Row(userId=268, movieId=2231, prediction=3.0407676696777344)
# Row(userId=553, movieId=2231, prediction=4.212759017944336)
# Row(userId=234, movieId=2231, prediction=4.221065521240234)
# Row(userId=239, movieId=2231, prediction=4.173404216766357)
# Row(userId=249, movieId=2231, prediction=4.117283821105957)
# Row(userId=510, movieId=2231, prediction=2.653623580932617)
# Row(userId=414, movieId=2231, prediction=3.8940162658691406)
# Row(userId=68, movieId=2231, prediction=3.548794746398926)
# Row(userId=562, movieId=2231, prediction=4.249122619628906)
# Row(userId=516, movieId=2259, prediction=1.973402500152588)
# Row(userId=587, movieId=2259, prediction=2.3976070880889893)
# Row(userId=555, movieId=2259, prediction=2.666808843612671)
# Row(userId=34, movieId=2443, prediction=2.773063898086548)
# Row(userId=414, movieId=2443, prediction=2.95583176612854)
# Row(userId=603, movieId=2488, prediction=2.614590644836426)
# Row(userId=594, movieId=2488, prediction=1.7594423294067383)
# Row(userId=292, movieId=2748, prediction=0.10301880538463593)
# Row(userId=217, movieId=2748, prediction=0.4550626873970032)
# Row(userId=482, movieId=2748, prediction=-0.28971076011657715)
# Row(userId=462, movieId=3089, prediction=3.6518311500549316)
# Row(userId=610, movieId=3089, prediction=3.88189697265625)
# Row(userId=275, movieId=3089, prediction=4.234381198883057)
# Row(userId=410, movieId=3089, prediction=3.5192432403564453)
# Row(userId=384, movieId=3098, prediction=3.1723945140838623)
# Row(userId=603, movieId=3098, prediction=3.567298412322998)
# Row(userId=479, movieId=3098, prediction=3.7462658882141113)
# Row(userId=202, movieId=3098, prediction=3.8185322284698486)
# Row(userId=100, movieId=3098, prediction=3.6041622161865234)
# Row(userId=288, movieId=3098, prediction=3.3018529415130615)
# Row(userId=70, movieId=3098, prediction=3.688049077987671)
# Row(userId=182, movieId=3986, prediction=1.4950647354125977)
# Row(userId=380, movieId=3986, prediction=3.3548362255096436)
# Row(userId=351, movieId=3986, prediction=1.9770795106887817)
# Row(userId=608, movieId=3986, prediction=2.714963436126709)
# Row(userId=422, movieId=3986, prediction=2.923373222351074)
# Row(userId=233, movieId=4239, prediction=3.074617385864258)
# Row(userId=246, movieId=4239, prediction=4.303933143615723)
# Row(userId=325, movieId=4239, prediction=3.399909496307373)
# Row(userId=603, movieId=4239, prediction=3.025209665298462)
# Row(userId=64, movieId=4239, prediction=3.6264803409576416)
# Row(userId=489, movieId=4239, prediction=2.8257036209106445)
# Row(userId=318, movieId=4239, prediction=3.677495241165161)
# Row(userId=4, movieId=4239, prediction=2.804795503616333)
# Row(userId=585, movieId=4239, prediction=3.830653190612793)
# Row(userId=438, movieId=4239, prediction=3.620661497116089)
# Row(userId=234, movieId=4239, prediction=3.7487716674804688)
# Row(userId=351, movieId=4239, prediction=3.4547252655029297)
# Row(userId=200, movieId=4239, prediction=3.9261281490325928)
# Row(userId=354, movieId=4239, prediction=3.6261255741119385)
# Row(userId=413, movieId=4239, prediction=4.146910667419434)
# Row(userId=68, movieId=4239, prediction=3.2376608848571777)
# Row(userId=198, movieId=4239, prediction=3.627662181854248)
# Row(userId=600, movieId=4239, prediction=2.9835355281829834)
# Row(userId=119, movieId=4239, prediction=4.131683349609375)
# Row(userId=573, movieId=4239, prediction=4.117269992828369)
# Row(userId=18, movieId=4239, prediction=3.609968423843384)
# Row(userId=414, movieId=5074, prediction=2.7459867000579834)
# Row(userId=415, movieId=5308, prediction=2.6126511096954346)
# Row(userId=427, movieId=5308, prediction=2.1780717372894287)
# Row(userId=561, movieId=5308, prediction=2.586533308029175)
# Row(userId=517, movieId=5308, prediction=3.433699131011963)
# Row(userId=606, movieId=32291, prediction=1.6728267669677734)
# Row(userId=599, movieId=32291, prediction=1.326147437095642)
# Row(userId=480, movieId=32291, prediction=1.6040599346160889)
# Row(userId=600, movieId=32291, prediction=1.5752043724060059)
# Row(userId=483, movieId=32554, prediction=4.013119220733643)
# Row(userId=580, movieId=33437, prediction=3.296767234802246)
# Row(userId=599, movieId=33437, prediction=2.0172159671783447)
# Row(userId=380, movieId=33437, prediction=3.3309733867645264)
# Row(userId=414, movieId=33437, prediction=2.6749932765960693)
# Row(userId=111, movieId=33615, prediction=2.8776261806488037)
# Row(userId=308, movieId=33615, prediction=2.914180278778076)
# Row(userId=425, movieId=33615, prediction=3.142745018005371)
# Row(userId=380, movieId=33615, prediction=3.57698655128479)
# Row(userId=129, movieId=33615, prediction=3.551342725753784)
# ...
# Row(userId=208, movieId=1277, prediction=3.4181532859802246)
# Row(userId=555, movieId=1359, prediction=2.668412685394287)
# Row(userId=482, movieId=1359, prediction=3.528818368911743)
# Row(userId=177, movieId=1882, prediction=1.3579127788543701)
# Row(userId=474, movieId=1882, prediction=1.742353081703186)
# Row(userId=19, movieId=1882, prediction=1.6091057062149048)
# Row(userId=489, movieId=1882, prediction=1.058075189590454)
# Row(userId=197, movieId=1882, prediction=1.6673506498336792)
# Row(userId=555, movieId=1882, prediction=1.7464838027954102)
# Row(userId=249, movieId=1882, prediction=1.8549566268920898)
# Row(userId=156, movieId=1882, prediction=1.7306170463562012)
# Row(userId=219, movieId=1882, prediction=1.8452208042144775)
# Row(userId=608, movieId=1882, prediction=0.9575655460357666)
# Row(userId=68, movieId=1882, prediction=1.6449189186096191)
# Row(userId=274, movieId=1993, prediction=0.7366130352020264)
# Row(userId=603, movieId=2057, prediction=2.4761879444122314)
# Row(userId=288, movieId=2057, prediction=2.785886526107788)
# Row(userId=387, movieId=2208, prediction=2.5312533378601074)
# Row(userId=477, movieId=2208, prediction=3.0125932693481445)
# Row(userId=186, movieId=2208, prediction=4.107105255126953)
# Row(userId=312, movieId=2454, prediction=3.37387752532959)
# Row(userId=469, movieId=2454, prediction=3.0835366249084473)
# Row(userId=571, movieId=2454, prediction=2.5765857696533203)
# Row(userId=474, movieId=2558, prediction=2.021679401397705)
# Row(userId=453, movieId=2558, prediction=2.142930746078491)
# Row(userId=177, movieId=2746, prediction=2.394653081893921)
# Row(userId=325, movieId=2746, prediction=3.2186594009399414)
# Row(userId=64, movieId=2746, prediction=3.397472381591797)
# Row(userId=554, movieId=2746, prediction=2.517313241958618)
# Row(userId=307, movieId=2746, prediction=2.6301910877227783)
# Row(userId=391, movieId=2746, prediction=3.124109983444214)
# Row(userId=448, movieId=2746, prediction=3.164350748062134)
# Row(userId=45, movieId=2746, prediction=3.308030128479004)
# Row(userId=68, movieId=2746, prediction=2.3613216876983643)
# Row(userId=135, movieId=2746, prediction=3.590003252029419)
# Row(userId=483, movieId=2746, prediction=3.217904806137085)
# Row(userId=275, movieId=3046, prediction=3.0604333877563477)
# Row(userId=414, movieId=3444, prediction=2.5285532474517822)
# Row(userId=561, movieId=3444, prediction=2.387434720993042)
# Row(userId=409, movieId=3846, prediction=3.90622878074646)
# Row(userId=469, movieId=3846, prediction=3.81453537940979)
# Row(userId=319, movieId=6942, prediction=3.77268385887146)
# Row(userId=132, movieId=6942, prediction=2.763679027557373)
# Row(userId=570, movieId=6942, prediction=3.187856912612915)
# Row(userId=489, movieId=6942, prediction=2.754629611968994)
# Row(userId=610, movieId=6942, prediction=3.571404457092285)
# Row(userId=166, movieId=6942, prediction=3.5769591331481934)
# Row(userId=63, movieId=6942, prediction=3.0990145206451416)
# Row(userId=509, movieId=6942, prediction=3.1413493156433105)
# Row(userId=10, movieId=6942, prediction=2.928445339202881)
# Row(userId=288, movieId=6942, prediction=3.226363182067871)
# Row(userId=256, movieId=6942, prediction=4.126443386077881)
# Row(userId=490, movieId=6942, prediction=2.63584566116333)
# Row(userId=414, movieId=6942, prediction=3.4680018424987793)
# Row(userId=68, movieId=6942, prediction=3.370457410812378)
# Row(userId=522, movieId=6942, prediction=3.5197300910949707)
# Row(userId=215, movieId=6942, prediction=3.590435743331909)
# Row(userId=606, movieId=7624, prediction=2.5284249782562256)
# Row(userId=414, movieId=36535, prediction=3.7709453105926514)
# Row(userId=153, movieId=36535, prediction=3.0829250812530518)
# Row(userId=274, movieId=47640, prediction=2.833810329437256)
# Row(userId=484, movieId=47640, prediction=2.4596543312072754)
# Row(userId=326, movieId=58554, prediction=1.8963053226470947)
# Row(userId=332, movieId=65514, prediction=3.2699246406555176)
# Row(userId=305, movieId=65514, prediction=2.7841384410858154)
# Row(userId=408, movieId=65514, prediction=3.464216947555542)
# Row(userId=534, movieId=65514, prediction=3.3369526863098145)
# Row(userId=105, movieId=65514, prediction=3.1778318881988525)
# Row(userId=111, movieId=81564, prediction=2.789301633834839)
# Row(userId=177, movieId=81564, prediction=2.8410158157348633)
# Row(userId=582, movieId=81564, prediction=3.321220636367798)
# Row(userId=448, movieId=81564, prediction=2.964578151702881)
# Row(userId=414, movieId=81564, prediction=3.400371789932251)
# Row(userId=523, movieId=82169, prediction=3.700629711151123)
# Row(userId=586, movieId=82169, prediction=3.910305976867676)
# Row(userId=509, movieId=82169, prediction=2.909562587738037)
# Row(userId=380, movieId=108945, prediction=2.428863763809204)
# Row(userId=298, movieId=108945, prediction=1.3318381309509277)
# Row(userId=41, movieId=138036, prediction=2.4536032676696777)
# Row(userId=318, movieId=138036, prediction=3.1977643966674805)
# Row(userId=564, movieId=138036, prediction=2.933371067047119)
# Row(userId=73, movieId=138036, prediction=3.448164463043213)
# Row(userId=408, movieId=138036, prediction=3.6014678478240967)
# Row(userId=105, movieId=138036, prediction=3.3866240978240967)
# Row(userId=561, movieId=138036, prediction=2.9991824626922607)
# Row(userId=119, movieId=138036, prediction=3.6006908416748047)
# Row(userId=599, movieId=89, prediction=2.277752637863159)
# Row(userId=132, movieId=89, prediction=2.4161555767059326)
# Row(userId=19, movieId=422, prediction=2.478048324584961)
# Row(userId=603, movieId=517, prediction=2.3222498893737793)
# Row(userId=217, movieId=517, prediction=2.6997694969177246)
# Row(userId=474, movieId=1413, prediction=2.9497547149658203)
# Row(userId=375, movieId=1476, prediction=3.7452077865600586)
# Row(userId=593, movieId=1476, prediction=2.4001624584198)
# Row(userId=274, movieId=1476, prediction=3.282487392425537)
# Row(userId=500, movieId=1476, prediction=2.572815179824829)
# Row(userId=438, movieId=1476, prediction=3.5634658336639404)
# Row(userId=298, movieId=1476, prediction=2.814741373062134)
# Row(userId=68, movieId=1476, prediction=2.8909056186676025)
# Row(userId=600, movieId=1476, prediction=3.2525277137756348)
# Row(userId=292, movieId=2376, prediction=3.1956589221954346)
# Row(userId=590, movieId=2376, prediction=2.637056827545166)
# Row(userId=387, movieId=2376, prediction=2.1827640533447266)
# Row(userId=555, movieId=2376, prediction=3.331153154373169)
# Row(userId=380, movieId=2376, prediction=3.7739789485931396)
# Row(userId=288, movieId=2376, prediction=2.8641040325164795)
# Row(userId=354, movieId=2376, prediction=3.2076199054718018)
# Row(userId=36, movieId=2376, prediction=1.5734997987747192)
# Row(userId=597, movieId=2457, prediction=3.924534320831299)
# Row(userId=183, movieId=2457, prediction=3.474889039993286)
# Row(userId=414, movieId=2457, prediction=3.4894611835479736)
# Row(userId=274, movieId=2555, prediction=1.1739418506622314)
# Row(userId=392, movieId=2706, prediction=1.940800666809082)
# Row(userId=255, movieId=2706, prediction=1.479973554611206)
# Row(userId=597, movieId=2706, prediction=2.938028335571289)
# Row(userId=101, movieId=2706, prediction=2.9897236824035645)
# Row(userId=606, movieId=2706, prediction=3.0177431106567383)
# Row(userId=409, movieId=2706, prediction=2.5076205730438232)
# Row(userId=232, movieId=2706, prediction=3.49115252494812)
# Row(userId=177, movieId=2706, prediction=3.432645797729492)
# Row(userId=603, movieId=2706, prediction=2.2308170795440674)
# Row(userId=274, movieId=2706, prediction=2.8214590549468994)
# Row(userId=280, movieId=2706, prediction=3.6373322010040283)
# Row(userId=432, movieId=2706, prediction=3.843374252319336)
# Row(userId=57, movieId=2706, prediction=2.8803884983062744)
# Row(userId=419, movieId=2706, prediction=3.0902602672576904)
# Row(userId=327, movieId=2706, prediction=5.0808868408203125)
# Row(userId=552, movieId=2706, prediction=2.2193500995635986)
# Row(userId=594, movieId=2706, prediction=3.6256215572357178)
# Row(userId=495, movieId=2706, prediction=2.9648356437683105)
# Row(userId=453, movieId=2706, prediction=3.2476134300231934)
# Row(userId=438, movieId=2706, prediction=3.119878053665161)
# Row(userId=249, movieId=2706, prediction=3.3782155513763428)
# Row(userId=226, movieId=2706, prediction=2.6586074829101562)
# Row(userId=608, movieId=2706, prediction=3.6928040981292725)
# Row(userId=298, movieId=2706, prediction=1.3359506130218506)
# Row(userId=342, movieId=2706, prediction=3.5270297527313232)
# Row(userId=522, movieId=2706, prediction=3.0701210498809814)
# Row(userId=42, movieId=2706, prediction=2.87080717086792)
# Row(userId=201, movieId=2706, prediction=3.3166215419769287)
# Row(userId=535, movieId=2706, prediction=1.6223535537719727)
# Row(userId=144, movieId=2706, prediction=3.1067841053009033)
# Row(userId=182, movieId=3053, prediction=3.5004866123199463)
# Row(userId=568, movieId=3053, prediction=3.865016460418701)
# Row(userId=390, movieId=3053, prediction=3.7407283782958984)
# Row(userId=414, movieId=3053, prediction=3.5409200191497803)
# Row(userId=587, movieId=3406, prediction=2.4399213790893555)
# Row(userId=606, movieId=3668, prediction=3.4211714267730713)
# Row(userId=12, movieId=3668, prediction=3.7568862438201904)
# Row(userId=599, movieId=3668, prediction=2.4853878021240234)
# Row(userId=202, movieId=3668, prediction=3.452580213546753)
# Row(userId=387, movieId=3668, prediction=2.918712854385376)
# Row(userId=599, movieId=3825, prediction=1.6052782535552979)
# Row(userId=182, movieId=3825, prediction=1.7929613590240479)
# Row(userId=484, movieId=3825, prediction=2.9294722080230713)
# Row(userId=489, movieId=3825, prediction=1.8859188556671143)
# Row(userId=543, movieId=3825, prediction=4.0879292488098145)
# Row(userId=226, movieId=3825, prediction=2.0288643836975098)
# Row(userId=256, movieId=3825, prediction=3.416499137878418)
# Row(userId=68, movieId=3825, prediction=2.7373056411743164)
# Row(userId=466, movieId=3825, prediction=3.229348659515381)
# Row(userId=562, movieId=3825, prediction=2.964378833770752)
# Row(userId=368, movieId=3836, prediction=3.6261162757873535)
# Row(userId=91, movieId=3836, prediction=3.753657102584839)
# Row(userId=474, movieId=3836, prediction=3.799494743347168)
# Row(userId=57, movieId=3836, prediction=4.172791004180908)
# Row(userId=292, movieId=3836, prediction=3.4853575229644775)
# Row(userId=606, movieId=3910, prediction=3.8578269481658936)
# Row(userId=246, movieId=3910, prediction=4.459522724151611)
# Row(userId=160, movieId=3910, prediction=3.9610657691955566)
# Row(userId=390, movieId=3910, prediction=4.323976516723633)
# Row(userId=414, movieId=3910, prediction=3.9205822944641113)
# Row(userId=600, movieId=3910, prediction=2.980358839035034)
# Row(userId=275, movieId=3910, prediction=4.658823013305664)
# Row(userId=414, movieId=4585, prediction=3.6486403942108154)
# Row(userId=474, movieId=5391, prediction=3.5145206451416016)
# Row(userId=414, movieId=6153, prediction=0.9171136021614075)
# Row(userId=580, movieId=6303, prediction=2.6370723247528076)
# Row(userId=377, movieId=6303, prediction=3.423316240310669)
# Row(userId=414, movieId=6303, prediction=3.6397898197174072)
# Row(userId=91, movieId=6638, prediction=2.027381181716919)
# Row(userId=34, movieId=6721, prediction=3.783334255218506)
# Row(userId=599, movieId=27788, prediction=2.057708263397217)
# Row(userId=125, movieId=27788, prediction=2.5965678691864014)
# Row(userId=382, movieId=40339, prediction=2.0490517616271973)
# Row(userId=580, movieId=46530, prediction=3.0910744667053223)
# Row(userId=232, movieId=46530, prediction=3.123964786529541)
# Row(userId=474, movieId=46530, prediction=2.9267380237579346)
# Row(userId=139, movieId=46530, prediction=1.4714490175247192)
# Row(userId=542, movieId=46530, prediction=2.3507637977600098)
# Row(userId=381, movieId=46530, prediction=3.5232768058776855)
# Row(userId=239, movieId=46530, prediction=3.496286153793335)
# Row(userId=219, movieId=46530, prediction=2.264979362487793)
# Row(userId=477, movieId=46530, prediction=3.2573986053466797)
# Row(userId=68, movieId=46530, prediction=2.691695213317871)
# Row(userId=517, movieId=46530, prediction=1.394057273864746)
# Row(userId=111, movieId=47518, prediction=2.6022260189056396)
# Row(userId=177, movieId=47518, prediction=2.7957687377929688)
# Row(userId=274, movieId=47518, prediction=1.9043487310409546)
# Row(userId=318, movieId=47518, prediction=2.6527249813079834)
# Row(userId=307, movieId=47518, prediction=2.349943161010742)
# Row(userId=73, movieId=47518, prediction=2.4575366973876953)
# Row(userId=298, movieId=47518, prediction=0.6976523399353027)
# Row(userId=89, movieId=47518, prediction=2.995781421661377)
# Row(userId=305, movieId=48304, prediction=4.055001735687256)
# Row(userId=274, movieId=48304, prediction=3.354787588119507)
# Row(userId=381, movieId=48304, prediction=3.5901403427124023)
# Row(userId=495, movieId=48304, prediction=4.2268900871276855)
# Row(userId=249, movieId=48304, prediction=3.905236005783081)
# Row(userId=525, movieId=48304, prediction=3.3970444202423096)
# Row(userId=573, movieId=48304, prediction=3.9192745685577393)
# Row(userId=606, movieId=48385, prediction=2.7900633811950684)
# Row(userId=305, movieId=48385, prediction=3.6333296298980713)
# Row(userId=473, movieId=48385, prediction=3.647892475128174)
# Row(userId=381, movieId=48385, prediction=2.478080987930298)
# Row(userId=610, movieId=48385, prediction=3.4493541717529297)
# Row(userId=307, movieId=48385, prediction=3.204594373703003)
# Row(userId=448, movieId=48385, prediction=2.579784870147705)
# Row(userId=543, movieId=48385, prediction=3.23807430267334)
# Row(userId=239, movieId=48385, prediction=2.9965760707855225)
# Row(userId=63, movieId=48385, prediction=3.3760673999786377)
# Row(userId=249, movieId=48385, prediction=3.331321954727173)
# Row(userId=73, movieId=48385, prediction=3.1374456882476807)
# Row(userId=62, movieId=48385, prediction=3.4570813179016113)
# Row(userId=125, movieId=48385, prediction=2.879704475402832)
# Row(userId=219, movieId=48385, prediction=3.354605197906494)
# Row(userId=200, movieId=48385, prediction=2.871504068374634)
# Row(userId=354, movieId=48385, prediction=2.8812332153320312)
# Row(userId=28, movieId=56367, prediction=3.172008752822876)
# Row(userId=232, movieId=56367, prediction=3.818042039871216)
# Row(userId=177, movieId=56367, prediction=3.586209774017334)
# Row(userId=305, movieId=56367, prediction=4.310415744781494)
# Row(userId=212, movieId=56367, prediction=3.4510984420776367)
# Row(userId=280, movieId=56367, prediction=3.843626022338867)
# Row(userId=227, movieId=56367, prediction=3.6702797412872314)
# Row(userId=41, movieId=56367, prediction=3.552732229232788)
# Row(userId=318, movieId=56367, prediction=3.6934821605682373)
# Row(userId=387, movieId=56367, prediction=2.797671318054199)
# Row(userId=503, movieId=56367, prediction=2.005202531814575)
# Row(userId=51, movieId=56367, prediction=4.724839210510254)
# Row(userId=356, movieId=56367, prediction=3.598280429840088)
# Row(userId=219, movieId=56367, prediction=2.5613765716552734)
# Row(userId=414, movieId=56367, prediction=3.2296605110168457)
# Row(userId=200, movieId=56367, prediction=4.096069812774658)
# Row(userId=487, movieId=56367, prediction=2.918470859527588)
# Row(userId=426, movieId=56367, prediction=2.7027933597564697)
# Row(userId=83, movieId=56367, prediction=3.544100522994995)
# Row(userId=89, movieId=56367, prediction=3.5439648628234863)
# Row(userId=599, movieId=64285, prediction=2.9206056594848633)
# Row(userId=448, movieId=64285, prediction=3.863816022872925)
# Row(userId=448, movieId=66785, prediction=2.7422516345977783)
# Row(userId=534, movieId=66785, prediction=3.182955265045166)
# Row(userId=483, movieId=66785, prediction=3.312347412109375)
# Row(userId=249, movieId=67923, prediction=2.910465955734253)
# Row(userId=414, movieId=67923, prediction=3.0568277835845947)
# Row(userId=534, movieId=67923, prediction=2.955193519592285)
# Row(userId=599, movieId=69849, prediction=2.7511324882507324)
# Row(userId=298, movieId=79008, prediction=2.6587681770324707)
# Row(userId=204, movieId=79008, prediction=3.921121835708618)
# Row(userId=454, movieId=79008, prediction=3.3708598613739014)
# Row(userId=484, movieId=84374, prediction=2.5193986892700195)
# Row(userId=448, movieId=84374, prediction=1.6108851432800293)
# Row(userId=448, movieId=145839, prediction=2.6637685298919678)

# %%
rmse = evaluator.evaluate(prediction1)
print("The RMSE for Optimal Grid Parameters with Cross Validation is: {}".format(rmse))
# Out:
# The RMSE for Optimal Grid Parameters with Cross Validation is: 0.9283467539309946

# %%
# %%time
#**************************************************************************
# Write PARQUET file
#**************************************************************************
best_pred.coalesce(10).write.mode('overwrite').parquet(dirPath + "best_pred_by_movieID_df" + ".parquet")

#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "best_pred_by_movieID_df" + ".parquet")
parquetdf.count()
parquetdf.show(10)

#predictions.show(n = 10)
#best_pred.show(10)
# Out:
# +------+-------+------+----------+----------+
# |userId|movieId|rating| timestamp|prediction|
# +------+-------+------+----------+----------+
# |   436|    536|     3| 833531946| 2.5542357|
# |   314|    536|     4| 834241987| 2.2407923|
# |    19|    611|     2| 965704056| 2.2289987|
# |   603|    612|     3| 963179060| 2.5626721|
# |    20|    783|     3|1054038251| 3.7072778|
# |   169|    783|     4|1059427166| 3.7481077|
# |   120|    783|     3| 860070141| 3.0107772|
# |    64|    783|     2|1161559862| 2.7501926|
# |   117|    783|     4| 844163543| 3.0780563|
# |   563|    783|     4|1441846374|  2.947924|
# +------+-------+------+----------+----------+
# only showing top 10 rows
#
# Wall time: 22 s

# %%
#predictions.join(movies_df, "movieId").select("userId", "title", "genres", "prediction").show(3)
#best_pred.join(movies_df, "movieId").select("userId", "title", "genres", "prediction").show(10)

best_pred_title_genre = best_pred.join(movies_df, "movieId").select("userId", "title", "genres", "prediction").sort("prediction", ascending=False)

# %%
# %%time
#**************************************************************************
# Write PARQUET file
#**************************************************************************
best_pred_title_genre.coalesce(10).write.mode('overwrite').parquet(dirPath + "best_pred_by_title_genre_df" + ".parquet")

#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "best_pred_by_title_genre_df" + ".parquet").sort("prediction", ascending=False)
parquetdf.count()
parquetdf.show(10)
# Out:
# +------+--------------------+--------------------+----------+
# |userId|               title|              genres|prediction|
# +------+--------------------+--------------------+----------+
# |   224|  Dying Young (1991)|       Drama|Romance| 6.6648426|
# |    53|Roman Holiday (1953)|Comedy|Drama|Romance|  6.507361|
# |   543|Tucker & Dale vs ...|       Comedy|Horror|  6.138631|
# |    53|River Runs Throug...|               Drama| 6.0811663|
# |   143|     Fired Up (2009)|              Comedy| 5.8134437|
# |    90|Beautiful Thing (...|       Drama|Romance| 5.7368402|
# |   580|         Dune (2000)|Drama|Fantasy|Sci-Fi| 5.6204157|
# |   224|Schindler's List ...|           Drama|War| 5.5456953|
# |   594|Walk to Remember,...|       Drama|Romance|  5.508151|
# |    25|Three Billboards ...|         Crime|Drama| 5.4913807|
# +------+--------------------+--------------------+----------+
# only showing top 10 rows
#
# Wall time: 45 s

# %% [markdown]
# ### Recommendations for One Selected User:

# %%
#selected_user_id = 597
#for_one_user = predictions.filter(col("userId") == selected_user_id).join(movies_df, "movieId").join(links_df, "movieId").select("userId", "title", "genres", "prediction")
#for_one_user = best_pred.filter(col("userId") == selected_user_id).join(movies_df, "movieId").join(links_df, "movieId").select("userId", "title", "genres", "prediction")

np.random.seed(42)
user_id = np.random.choice(numUsers)
for_one_user = best_pred.filter(col("userId") == user_id).join(movies_df, "movieId").join(links_df, "movieId").select("userId", "title", "genres", "prediction").sort("prediction", ascending=False)
for_one_user.show(10)
# Out:
# +------+--------------------+--------------------+----------+
# |userId|               title|              genres|prediction|
# +------+--------------------+--------------------+----------+
# |   102|Fugitive, The (1993)|            Thriller| 3.8864586|
# |   102|Interview with th...|        Drama|Horror| 3.6017718|
# |   102|         Dave (1993)|      Comedy|Romance| 3.3378823|
# |   102|Three Musketeers,...|Action|Adventure|...|  3.085153|
# |   102|Ace Ventura: Pet ...|              Comedy| 2.9737644|
# |   102|  Cliffhanger (1993)|Action|Adventure|...| 2.7643664|
# |   102|Beverly Hills Cop...|Action|Comedy|Cri...|  2.548684|
# |   102|       Casper (1995)|  Adventure|Children| 2.5242767|
# |   102|Under Siege 2: Da...|              Action| 2.3637016|
# |   102|City Slickers II:...|Adventure|Comedy|...| 2.2028992|
# +------+--------------------+--------------------+----------+

# %%
# %%time
#**************************************************************************
# Write PARQUET file
#**************************************************************************
for_one_user.coalesce(10).write.mode('overwrite').parquet(dirPath + "one_user_recs_df" + ".parquet")

#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "one_user_recs_df" + ".parquet")
parquetdf.count()
parquetdf.show(10)
# Out:
# +------+--------------------+--------------------+----------+
# |userId|               title|              genres|prediction|
# +------+--------------------+--------------------+----------+
# |   102|City Slickers II:...|Adventure|Comedy|...| 2.2028992|
# |   102|Interview with th...|        Drama|Horror| 3.6017718|
# |   102|Three Musketeers,...|Action|Adventure|...|  3.085153|
# |   102|Beverly Hills Cop...|Action|Comedy|Cri...|  2.548684|
# |   102|  Cliffhanger (1993)|Action|Adventure|...| 2.7643664|
# |   102|Under Siege 2: Da...|              Action| 2.3637016|
# |   102|Ace Ventura: Pet ...|              Comedy| 2.9737644|
# |   102|       Casper (1995)|  Adventure|Children| 2.5242767|
# |   102|Fugitive, The (1993)|            Thriller| 3.8864586|
# |   102|         Dave (1993)|      Comedy|Romance| 3.3378823|
# +------+--------------------+--------------------+----------+
#
# Wall time: 8.44 s

# %% [markdown]
# ### Top Predictions for Each User:

# %%
# Top recommendation for each user
#userRecom = model.recommendForAllUsers(10)
userRecom = best_model.recommendForAllUsers(10)

# Top recommendation for each movie
#movieRecom = model.recommendForAllItems(10)
movieRecom = best_model.recommendForAllItems(10)

# %%
userRecom.printSchema()
# Out:
# root
#  |-- userId: integer (nullable = false)
#  |-- recommendations: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- movieId: integer (nullable = true)
#  |    |    |-- rating: float (nullable = true)

# %%
userRecom.select("userId", "recommendations.movieId").show(10)
# Out:
# +------+--------------------+
# |userId|             movieId|
# +------+--------------------+
# |   471|[136469, 3235, 89...|
# |   463|[33649, 26928, 13...|
# |   496|[136469, 171495, ...|
# |   148|[33649, 3200, 259...|
# |   540|[33649, 6732, 269...|
# |   392|[8477, 40491, 257...|
# |   243|[3200, 25947, 336...|
# |    31|[86347, 172547, 4...|
# |   516|[86347, 4495, 823...|
# |   580|[4821, 183897, 78...|
# +------+--------------------+
# only showing top 10 rows

# %%
# %%time
#**************************************************************************
# Write PARQUET file
#**************************************************************************
userRecom.select("userId", "recommendations.movieId").coalesce(10).write.mode('overwrite').parquet(dirPath + "userRecom_df" + ".parquet")

#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "userRecom_df" + ".parquet").sort("userID", ascending=True)
parquetdf.count()
parquetdf.show(10)
# Out:
# +------+--------------------+
# |userId|             movieId|
# +------+--------------------+
# |     1|[25947, 33649, 32...|
# |     2|[4495, 6201, 8235...|
# |     3|[4509, 879, 26258...|
# |     4|[86347, 461, 4518...|
# |     5|[3235, 8235, 4495...|
# |     6|[86347, 4495, 620...|
# |     7|[26258, 25947, 84...|
# |     8|[8477, 25947, 320...|
# |     9|[8477, 25947, 257...|
# |    10|[86320, 26171, 11...|
# +------+--------------------+
# only showing top 10 rows
#
# Wall time: 13.8 s

# %% [markdown]
# ### Top Recommended Users for Each Movie:

# %%
movieRecom.printSchema()
# Out:
# root
#  |-- movieId: integer (nullable = false)
#  |-- recommendations: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- userId: integer (nullable = true)
#  |    |    |-- rating: float (nullable = true)

# %%
#movieRecom.select("movieId", "recommendations.userId","recommendations.rating").show(10)
movieRecom.select("movieId", "recommendations.userId").show(10)
# Out:
# +-------+--------------------+
# |movieId|              userId|
# +-------+--------------------+
# |   1580|[53, 543, 243, 43...|
# |   4900|[53, 43, 1, 360, ...|
# |   5300|[461, 236, 40, 10...|
# |   6620|[360, 258, 375, 5...|
# |   7340|[224, 554, 393, 5...|
# |  32460|[53, 43, 236, 40,...|
# |  54190|[53, 12, 452, 276...|
# |    471|[485, 536, 393, 4...|
# |   1591|[53, 224, 236, 38...|
# | 140541|[138, 55, 598, 20...|
# +-------+--------------------+
# only showing top 10 rows

# %%
# %%time
#**************************************************************************
# Write PARQUET file
#**************************************************************************
movieRecom.select("movieId", "recommendations.userId").coalesce(10).write.mode('overwrite').parquet(dirPath + "movieRecom_df" + ".parquet")

#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "movieRecom_df" + ".parquet")
parquetdf.count()
parquetdf.show(10)
# Out:
# +-------+--------------------+
# |movieId|              userId|
# +-------+--------------------+
# |   4520|[258, 53, 236, 27...|
# |  72330|[393, 224, 485, 2...|
# |   2841|[53, 543, 12, 276...|
# |   5941|[53, 543, 393, 54...|
# |  69251|[53, 543, 243, 27...|
# |  89761|[236, 224, 259, 2...|
# | 128991|[53, 276, 452, 12...|
# |   1732|[360, 258, 154, 3...|
# |   4662|[53, 360, 154, 24...|
# |   8372|[259, 329, 207, 5...|
# +-------+--------------------+
# only showing top 10 rows
#
# Wall time: 27.8 s

# %% [markdown]
# ## Recommendations for Movies the User Hasn't Previously Reviewed Yet
# We can further refine the recommender to filter out movies which the user has previously seen/reviewed.
#
# Let's now take a hyptothetical random user that has already rated some movies. We'll take a random user_id out the range of user id's in the dataset. Next, we get all of their ratings and sort to show the top 10 rated movies.

# %%
np.random.seed(42)
#user_id = np.random.choice(numUsers)

# %%
new_user_ratings = rating_df.filter(rating_df.userId == user_id)
new_user_ratings.sort('rating', ascending=True).take(10) # top rated movies for this user
# Out:
# [Row(userId=102, movieId=540, rating=1, timestamp=835877588),
#  Row(userId=102, movieId=204, rating=2, timestamp=835876471),
#  Row(userId=102, movieId=173, rating=2, timestamp=835876239),
#  Row(userId=102, movieId=329, rating=2, timestamp=835877081),
#  Row(userId=102, movieId=163, rating=3, timestamp=835877307),
#  Row(userId=102, movieId=23, rating=3, timestamp=835877570),
#  Row(userId=102, movieId=21, rating=3, timestamp=835876107),
#  Row(userId=102, movieId=172, rating=3, timestamp=835876471),
#  Row(userId=102, movieId=39, rating=3, timestamp=835876151),
#  Row(userId=102, movieId=165, rating=3, timestamp=835875790)]

# %%
new_user_ratings.describe('rating').show()
# Out:
# +-------+------------------+
# |summary|            rating|
# +-------+------------------+
# |  count|                56|
# |   mean| 3.357142857142857|
# | stddev|0.7960943623504901|
# |    min|                 1|
# |    max|                 5|
# +-------+------------------+

# %%
# %%time
#**************************************************************************
# Write PARQUET file
#**************************************************************************
new_user_ratings.coalesce(10).write.mode('overwrite').parquet(dirPath + "new_user_ratings_df" + ".parquet")
# Out:
# Wall time: 603 ms

# %%
# %%time
#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "new_user_ratings_df" + ".parquet")
parquetdf.count()
parquetdf.show()
# Out:
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |   102|      3|     5|840635033|
# |   102|      6|     3|835877535|
# |   102|     21|     3|835876107|
# |   102|     23|     3|835877570|
# |   102|     39|     3|835876151|
# |   102|     47|     5|835876045|
# |   102|    150|     3|835875691|
# |   102|    153|     3|835875790|
# |   102|    158|     3|835876534|
# |   102|    160|     3|835876194|
# |   102|    161|     3|835875943|
# |   102|    163|     3|835877307|
# |   102|    165|     3|835875790|
# |   102|    172|     3|835876471|
# |   102|    173|     2|835876239|
# |   102|    186|     3|835876384|
# |   102|    204|     2|835876471|
# |   102|    223|     5|835877270|
# |   102|    231|     3|835875836|
# |   102|    236|     3|835876272|
# +------+-------+------+---------+
# only showing top 20 rows
#
# Wall time: 231 ms

# %% [markdown]
# ### Remove Previously Reviewed Movies from Consideration:
#
# The following will get us a list of all movieIds not previously rated by the user. Additionally, unrated movies are required to have more  than 25 ratings in order not to be filtered out. This prevents movies which don't have many reviews from being recommended.

# %%
new_user_rated_movieIds = [i.movieId for i in new_user_ratings.select('movieId').distinct().collect()]
movieIds = [i.movieId for i in movies_counts.filter(movies_counts.counts > 25).select('movieId').distinct().collect()]
new_user_unrated_movieIds = list(set(movieIds) - set(new_user_rated_movieIds))
print(new_user_unrated_movieIds)
# Out:
# [1, 122882, 2, 5, 2054, 7, 122886, 10, 6155, 2058, 6157, 11, 122892, 2064, 16, 17, 19, 122900, 22, 57368, 25, 122904, 24, 2076, 30749, 2078, 31, 2080, 2081, 34, 2082, 29, 2085, 122918, 2087, 32, 5299, 36, 6188, 44, 2094, 48, 45, 50, 102445, 52, 4148, 2100, 51255, 2105, 58, 60, 2109, 116797, 88125, 62, 65, 88129, 2115, 70, 30793, 53322, 6218, 88140, 2124, 30810, 30812, 2140, 95, 2144, 2145, 88163, 92259, 2150, 104, 30825, 107, 110, 111, 112, 2161, 2160, 2167, 49272, 139385, 69757, 2174, 4223, 4226, 45186, 135, 4232, 6281, 141, 4239, 6287, 2193, 2194, 145, 4246, 151, 4262, 168, 8360, 8361, 170, 4270, 8368, 180, 2231, 2232, 185, 8376, 84152, 6333, 193, 2243, 196, 198, 106696, 2248, 4299, 208, 4306, 69844, 4308, 112852, 4310, 216, 2268, 6365, 224, 4321, 225, 59615, 2273, 6373, 2278, 6377, 6378, 235, 33004, 2288, 2289, 2291, 2294, 246, 4343, 4344, 2300, 2302, 252, 256, 260, 261, 4361, 265, 39183, 8464, 53519, 4369, 273, 2324, 277, 4370, 2321, 272, 2329, 282, 106782, 2335, 4128, 292, 4388, 300, 303, 2353, 2355, 2359, 316, 76093, 86332, 317, 57669, 327, 72011, 333, 2384, 8529, 8528, 164179, 339, 8533, 342, 337, 2393, 345, 2395, 2396, 348, 4446, 4447, 353, 96610, 355, 2403, 2407, 6503, 2409, 362, 119145, 2411, 6502, 367, 368, 370, 2420, 2421, 2423, 2424, 49530, 376, 2427, 2431, 108932, 6534, 45447, 59784, 104841, 6537, 6539, 6541, 33166, 2455, 410, 413, 2470, 8622, 431, 2478, 435, 2485, 441, 442, 45499, 2490, 8636, 8641, 8644, 2501, 2502, 455, 115149, 51662, 45517, 466, 55765, 471, 8665, 4571, 76251, 2529, 485, 2539, 2541, 2542, 494, 497, 2949, 98809, 47610, 508, 509, 915, 520, 2571, 2572, 524, 55820, 527, 152081, 529, 2580, 2581, 82459, 541, 4638, 543, 4641, 4643, 551, 2599, 555, 2605, 66097, 6708, 6711, 2616, 2617, 68157, 2628, 585, 587, 8783, 8784, 2640, 594, 596, 597, 2641, 595, 4700, 4701, 8798, 41566, 608, 2657, 6754, 610, 41569, 8807, 616, 4718, 2671, 4720, 628, 2683, 637, 4734, 166528, 6787, 2692, 2694, 647, 60040, 648, 2699, 2700, 2701, 70286, 68237, 94864, 653, 2706, 661, 2710, 6807, 2712, 45720, 45722, 2716, 2717, 671, 673, 2722, 2723, 2724, 78499, 80549, 60069, 88744, 8873, 8874, 60074, 4776, 2746, 708, 2761, 2762, 2763, 6863, 4816, 719, 2770, 720, 53972, 8917, 6870, 33493, 724, 74458, 6874, 733, 68319, 736, 2788, 741, 743, 2791, 745, 2795, 53996, 2797, 750, 94959, 4848, 54001, 1371, 2804, 8949, 8950, 762, 8957, 8961, 111362, 68358, 4874, 2826, 780, 8970, 4878, 783, 784, 778, 786, 8972, 785, 788, 6934, 4886, 6936, 8984, 4890, 6942, 4896, 6947, 805, 4901, 99114, 2858, 6957, 2871, 109374, 832, 837, 838, 2890, 33615, 849, 852, 858, 2908, 37729, 2915, 4963, 2916, 2918, 37733, 4973, 56174, 7022, 880, 4975, 4979, 2944, 4993, 898, 4995, 2947, 2948, 899, 903, 904, 2951, 2953, 902, 908, 909, 910, 33679, 912, 2959, 914, 5010, 916, 5013, 913, 919, 920, 2968, 922, 923, 924, 115617, 2985, 31658, 2987, 109487, 7090, 2997, 3000, 953, 3006, 95167, 72641, 5060, 31685, 5064, 969, 968, 31696, 3033, 3034, 3039, 7143, 7147, 3052, 7153, 134130, 54259, 35836, 1021, 1022, 1020, 54272, 3072, 33794, 115713, 1028, 1029, 1027, 1032, 3081, 3082, 1035, 1036, 54286, 1042, 1047, 97304, 3101, 1059, 3108, 1061, 74789, 1060, 3114, 56367, 1073, 1077, 1079, 1080, 52281, 1084, 1088, 1089, 1090, 1092, 1093, 1094, 1097, 3147, 3148, 1101, 7254, 3160, 3168, 1120, 5218, 5219, 64614, 3175, 1127, 1129, 3174, 3176, 1136, 3186, 1148, 7293, 27773, 5254, 3210, 111759, 148626, 5266, 1172, 38038, 1179, 1183, 44191, 44195, 44199, 1193, 1196, 1197, 1198, 1199, 1200, 1201, 38061, 1203, 3252, 3253, 1206, 1207, 1208, 3257, 1210, 3256, 3254, 1213, 1214, 58559, 3264, 87232, 1215, 7361, 1220, 3269, 1222, 1223, 1219, 1225, 3273, 1221, 3275, 7373, 1230, 1228, 1233, 1234, 1235, 3285, 1240, 1242, 1244, 1246, 1247, 1249, 1250, 1252, 3301, 3300, 5349, 54503, 1257, 1258, 1259, 1261, 1262, 1263, 51540, 1265, 1266, 1267, 79091, 1269, 1270, 1271, 1272, 1274, 1275, 1276, 1278, 34048, 5377, 5378, 1282, 48385, 1285, 1287, 1288, 48394, 1291, 5388, 1293, 7438, 60684, 1299, 7445, 1302, 95510, 130 ...

# %%
import time
from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)
num_ratings = len(new_user_unrated_movieIds)
cols = ('userId', 'movieId', 'timestamp')
timestamps = [int(time.time())] * num_ratings
userIds = [user_id] * num_ratings
# ratings = [0] * num_ratings
new_user_preds = sqlContext.createDataFrame(zip(userIds, new_user_unrated_movieIds, timestamps), cols)

# %%
new_user_preds = best_model.transform(new_user_preds).filter(col('prediction') != np.nan)

# %%
new_user_preds.sort('prediction', ascending=False).take(10)
# Out:
# [Row(userId=102, movieId=898, timestamp=1652843132, prediction=4.401188850402832),
#  Row(userId=102, movieId=750, timestamp=1652843132, prediction=4.3704986572265625),
#  Row(userId=102, movieId=720, timestamp=1652843132, prediction=4.321457386016846),
#  Row(userId=102, movieId=2019, timestamp=1652843132, prediction=4.2671098709106445),
#  Row(userId=102, movieId=1148, timestamp=1652843132, prediction=4.2554497718811035),
#  Row(userId=102, movieId=1223, timestamp=1652843132, prediction=4.244061470031738),
#  Row(userId=102, movieId=858, timestamp=1652843132, prediction=4.236511707305908),
#  Row(userId=102, movieId=2959, timestamp=1652843132, prediction=4.235004425048828),
#  Row(userId=102, movieId=1250, timestamp=1652843132, prediction=4.23486852645874),
#  Row(userId=102, movieId=1136, timestamp=1652843132, prediction=4.220710277557373)]

# %% [markdown]
# ### Top  Recommendations for Movies not Previously Reviewed by the User:
#
# Here we see the top recommendations for movies which a particular user hasn't previously reviewed. This lets the user choose movies that are new to them. For simplicity, it is assumed that movies that haven't been reviewed by the user have also not yet been viewed by the user.

# %%
#one_user_unrated_df = new_user_preds.filter(col("userId") == user_id).join(movies_df, "movieId").join(links_df, "movieId").select("userId", "title", "genres", "prediction")
one_user_unrated_df = new_user_preds.filter(col("userId") == user_id).join(movies_df, "movieId").join(links_df, "movieId").select("userId", "title", "genres", "prediction").sort('prediction', ascending=False)
one_user_unrated_df.show(10)
# Out:
# +------+--------------------+--------------------+----------+
# |userId|               title|              genres|prediction|
# +------+--------------------+--------------------+----------+
# |   102|Philadelphia Stor...|Comedy|Drama|Romance|  4.401189|
# |   102|Dr. Strangelove o...|          Comedy|War| 4.3704987|
# |   102|Wallace & Gromit:...|Adventure|Animati...| 4.3214574|
# |   102|Seven Samurai (Sh...|Action|Adventure|...|   4.26711|
# |   102|Wallace & Gromit:...|Animation|Childre...|   4.25545|
# |   102|Grand Day Out wit...|Adventure|Animati...| 4.2440615|
# |   102|Godfather, The (1...|         Crime|Drama| 4.2365117|
# |   102|   Fight Club (1999)|Action|Crime|Dram...| 4.2350044|
# |   102|Bridge on the Riv...| Adventure|Drama|War| 4.2348685|
# |   102|Monty Python and ...|Adventure|Comedy|...| 4.2207103|
# +------+--------------------+--------------------+----------+
# only showing top 10 rows

# %%
#===============================================================
#===============================================================
# PARQUET
#===============================================================
#===============================================================

# %%
# %%time
#**************************************************************************
# Write PARQUET file
#**************************************************************************
one_user_unrated_df.coalesce(10).write.mode('overwrite').parquet(dirPath + "one_user_unrated_df" + ".parquet")
# Out:
# Wall time: 12.6 s

# %%
# %%time
#**************************************************************************
# Read PARQUET file
#**************************************************************************
parquetdf = spark.read.parquet(dirPath + "one_user_unrated_df" + ".parquet")
parquetdf.count()
parquetdf.show(10)
# Out:
# +------+--------------------+--------------------+----------+
# |userId|               title|              genres|prediction|
# +------+--------------------+--------------------+----------+
# |   102|Philadelphia Stor...|Comedy|Drama|Romance|  4.401189|
# |   102|Dr. Strangelove o...|          Comedy|War| 4.3704987|
# |   102|Wallace & Gromit:...|Adventure|Animati...| 4.3214574|
# |   102|Seven Samurai (Sh...|Action|Adventure|...|   4.26711|
# |   102|Wallace & Gromit:...|Animation|Childre...|   4.25545|
# |   102|Grand Day Out wit...|Adventure|Animati...| 4.2440615|
# |   102|Godfather, The (1...|         Crime|Drama| 4.2365117|
# |   102|   Fight Club (1999)|Action|Crime|Dram...| 4.2350044|
# |   102|Bridge on the Riv...| Adventure|Drama|War| 4.2348685|
# |   102|Monty Python and ...|Adventure|Comedy|...| 4.2207103|
# +------+--------------------+--------------------+----------+
# only showing top 10 rows
#
# Wall time: 478 ms
